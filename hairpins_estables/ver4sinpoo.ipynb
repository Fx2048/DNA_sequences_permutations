# %%
# Instala conda (si no está instalado)
# !pip install -q condacolab
import condacolab
condacolab.install()

# Instala ViennaRNA desde conda-forge
# !conda install -c bioconda viennarna -y

# Verifica instalación
# !RNAfold --version
# !RNAplot --version
# Out:
# ✨🍰✨ Everything looks OK!
# Channels:
#  - bioconda
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# RNAfold 2.7.0
# RNAplot 2.7.0

# %%
# !apt-get install viennarna -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package viennarna

# %%
# !sudo apt update
# !sudo apt install ghostscript
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,085 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,812 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,373 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,803 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,796 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,452 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,288 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,043 kB]
# Fetched 36.7 MB in 5s (7,788 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 40 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 10 newly installed, 0 to remove and 40 not upgraded.
# Need to get 16.7 MB of archives.
# After this operation, 63.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.13 [753 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.13 [5,032 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.13 [49.4 kB]
# Fetched 16.7 MB in 2s (8,255 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../0-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../1-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../2-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../3-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../4-libgs9-common_9.55.0~dfsg1-0ubuntu5.13_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../5-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../6-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../7-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../8-libgs9_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../9-ghostscript_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/liblzma.so.5 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !gs --version
# Out:
# 9.55.0

# %% [markdown]
# version corregida que pregunta si quiere con filtro de energía o no??:

# %%
# version 2
#!/usr/bin/env python3
"""
gen_vienna_hairpins.py v2.7

Genera M secuencias P(14)-Q(4)-R(14)-S(21), valida con ViennaRNA (RNAfold),
rechaza secuencias que formen más de 1 horquilla o donde Q empareje con P/R,
genera imágenes (RNAplot + gs), guarda resultados en formato Vienna.

Compatible con ViennaRNA 2.7.0

Requisitos:
 - RNAfold y RNAplot en PATH (ViennaRNA 2.7+)
 - Ghostscript 'gs' (para PNG)
"""

import random
import subprocess
import shutil
import os
import sys
import glob
import math
import time
from typing import Set, Tuple, List, Dict

# Parámetros del esquema (fijos según tu especificación)
P = 14
Q = 4
R = 14
S = 21
MIN_LEN = P + Q + R + S  # 53

# Random seed para reproducibilidad (opcional)
random.seed()

# Complemento ADN
COMP = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

def complement_base(b: str) -> str:
    return COMP.get(b.upper(), 'N')

def complement_reverse(seq: str) -> str:
    return ''.join(complement_base(c) for c in reversed(seq))

def random_seq(length: int) -> str:
    return ''.join(random.choice(['A','C','G','T']) for _ in range(length))

# --- Dot-bracket -> pares (i,j) ---
def pairs_from_dotbracket(db: str) -> Set[Tuple[int,int]]:
    stack = []
    pairs = set()
    for i, ch in enumerate(db):
        if ch == '(':
            stack.append(i)
        elif ch == ')':
            if not stack:
                continue
            j = stack.pop()
            a, b = (j, i) if j < i else (i, j)
            pairs.add((a,b))
    return pairs

# --- Pares diseñados P<->R (índices 0-based) ---
def designed_pairs_indices(P_len: int, Q_len: int, R_len: int) -> Set[Tuple[int,int]]:
    """
    Para i in [0..P_len-1] -> j = P_len + Q_len + (R_len-1 - i)
    """
    pairs = set()
    for i in range(min(P_len, R_len)):
        j = P_len + Q_len + (R_len - 1 - i)
        a, b = (i, j) if i < j else (j, i)
        pairs.add((a,b))
    return pairs

DESIGNED_PAIRS = designed_pairs_indices(P, Q, R)

# --- Ejecutar RNAfold --noPS sobre una secuencia y parsear salida ---
def evaluate_with_rnafold(seq: str, temp: float = 60.0) -> Tuple[str, float]:
    if not shutil.which('RNAfold'):
        raise RuntimeError("RNAfold no encontrado en PATH.")
    try:
        proc = subprocess.run(
            ['RNAfold', '--noPS', f'--temp={temp}'],
            input=seq.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True
        )
        out = proc.stdout.decode().strip().splitlines()
        struct_line = out[1].strip()
        parts = struct_line.split()
        struct = parts[0]
        energy = float(parts[-1].strip('()'))
        return struct, energy
    except subprocess.CalledProcessError as e:
        raise RuntimeError(f"Error RNAfold: {e.stderr.decode()}")

# Calcular fracción apareada (θ) explícitamente: θ = 1/(1+e^[ΔG/(RT)])
def fraction_paired(energy_kcal, temp_C):
    """
    Calcula la fracción de moléculas en estado apareado a una temperatura dada.
    """
    R = 0.001987  # kcal/(mol·K)
    T = temp_C + 273.15
    return 1 / (1 + math.exp(energy_kcal / (R * T)))

# --- Generar imagen usando RNAplot (v2.7 compatible) y convertir a PNG ---
def plot_structure(seq: str, struct: str, seq_idx: int) -> Tuple[str, str]:
    """
    Genera archivos seq_{idx}_ss.ps y seq_{idx}.png en carpeta plots/
    Compatible con RNAplot 2.7.0 (sin opciones -o)
    Retorna (ps_path, png_path)
    """
    if not shutil.which('RNAplot'):
        raise RuntimeError("RNAplot no encontrado en PATH.")

    # Verificar que longitudes coincidan
    if len(seq) != len(struct):
        raise RuntimeError(f"Longitudes no coinciden: seq={len(seq)}, struct={len(struct)}")

    # Nombres de archivos finales
    base = f"seq_{seq_idx}"
    ps_path = os.path.join('plots', f"{base}_ss.ps")
    png_path = os.path.join('plots', f"{base}.png")

    input_text = f"{seq}\n{struct}\n"

    # Guardar directorio original
    original_dir = os.getcwd()

    try:
        # Cambiar a directorio plots para que RNAplot genere archivos ahí
        os.chdir('plots')

        # Limpiar archivos PS/EPS antiguos en el directorio
        for old_file in glob.glob('*.ps') + glob.glob('*.eps'):
            try:
                os.remove(old_file)
            except:
                pass

        # RNAplot 2.7 lee stdin y genera rna_ss.ps
        proc = subprocess.run(
            ["RNAplot"],
            input=input_text,
            text=True,
            capture_output=True
        )

        # Verificar si hubo error
        if proc.returncode != 0:
            raise RuntimeError(f"RNAplot falló: {proc.stderr}")

        # Esperar un momento para que el archivo se escriba completamente
        time.sleep(0.1)

        # Buscar archivo .ps o .eps generado (intentar varios nombres comunes)
        possible_names = ['rna_ss.ps', 'rna.ps', 'rna.eps', 'ss.ps']
        generated_ps = None

        for name in possible_names:
            if os.path.exists(name):
                generated_ps = name
                break

        # Si no encontramos ninguno, buscar cualquier .ps/.eps
        if not generated_ps:
            ps_files = glob.glob('*.ps') + glob.glob('*.eps')
            if ps_files:
                generated_ps = ps_files[0]

        if not generated_ps:
            # Debug: listar todos los archivos
            all_files = os.listdir('.')
            raise RuntimeError(f"RNAplot no generó archivo PS/EPS. Archivos en plots/: {all_files}. stderr: {proc.stderr}")

        # Archivo encontrado
        final_ps_name = f"{base}_ss.ps"

        # Renombrar si es necesario
        if generated_ps != final_ps_name:
            if os.path.exists(final_ps_name):
                os.remove(final_ps_name)
            os.rename(generated_ps, final_ps_name)

        ps_path = os.path.join(os.getcwd(), final_ps_name)

        # Convertir a PNG con Ghostscript
        png_created = ''
        if shutil.which('gs'):
            try:
                png_name = f"{base}.png"
                # Ghostscript necesita -dEPSCrop para archivos EPS
                result = subprocess.run([
                    "gs", "-dSAFER", "-dBATCH", "-dNOPAUSE", "-dQUIET",
                    "-dEPSCrop",  # Importante para archivos EPS
                    "-sDEVICE=pngalpha", "-r300",  # Aumentar resolución a 300 DPI
                    f"-sOutputFile={png_name}", final_ps_name
                ], capture_output=True)

                if result.returncode != 0:
                    raise RuntimeError(f"Ghostscript error: {result.stderr.decode()}")

                if os.path.exists(png_name):
                    png_created = os.path.join(os.getcwd(), png_name)
                else:
                    raise RuntimeError(f"PNG no se generó: {png_name}")

            except Exception as e:
                print(f"  ⚠️  Ghostscript falló para seq_{seq_idx}: {e}")
        else:
            print(f"  ⚠️  'gs' no encontrado; solo .ps disponible para seq_{seq_idx}")

        return ps_path, png_created

    except Exception as e:
        raise RuntimeError(f"Error en plot_structure: {e}")
    finally:
        # Volver al directorio original
        os.chdir(original_dir)

# --- Validación de estructura ---
def analyze_structure_validity(struct: str, seq_len: int, P_len: int, Q_len: int, R_len: int) -> Tuple[bool, str]:
    """
    Retorna (valid, message). valid=True si:
      - Los pares coinciden exactamente con DESIGNED_PAIRS
      - Q no forma pares con P o R
    """
    pred_pairs = pairs_from_dotbracket(struct)
    extra_pairs = pred_pairs - DESIGNED_PAIRS
    missing_pairs = DESIGNED_PAIRS - pred_pairs

    q_start = P_len
    q_end = P_len + Q_len - 1
    q_pairs = [p for p in pred_pairs if (q_start <= p[0] <= q_end) or (q_start <= p[1] <= q_end)]

    if extra_pairs:
        return False, f"Pares extra detectados ({len(extra_pairs)})."
    if missing_pairs:
        return False, f"Pares faltantes del stem ({len(missing_pairs)})."
    if q_pairs:
        return False, f"Loop Q presenta emparejamientos no permitidos."
    return True, "Válida"

# --- Generador principal ---
def generate_M_sequences(M: int, max_attempts=10000, energy_filter=None) -> List[Dict]:
    """
    Genera hasta M secuencias válidas.

    Args:
        M: Número de secuencias a generar
        max_attempts: Máximo número de intentos
        energy_filter: Tupla (min, max) para filtrar por energía. None = sin filtro

    Retorna lista de dicts: id, seq, struct, energy, frac, ps, png
    """
    if M <= 0:
        raise ValueError("M debe ser > 0")

    os.makedirs("plots", exist_ok=True)
    accepted = []
    seen = set()
    attempts = 0
    rejected_by_energy = 0

    while len(accepted) < M and attempts < max_attempts:
        attempts += 1

        # Generar secuencia P-Q-R-S
        p_seq = random_seq(P)
        q_seq = random_seq(Q) if Q > 0 else ''
        r_seq = complement_reverse(p_seq)
        s_seq = random_seq(S) if S > 0 else ''
        full_seq = p_seq + q_seq + r_seq + s_seq

        if full_seq in seen:
            continue
        seen.add(full_seq)

        # Evaluar con RNAfold
        try:
            struct, energy = evaluate_with_rnafold(full_seq, temp=60.0)
        except Exception as e:
            print(f"❌ Error RNAfold: {e}")
            continue

        # Validar estructura
        valid, msg = analyze_structure_validity(struct, len(full_seq), P, Q, R)
        if not valid:
            print(f"[RECHAZADA] intento {attempts}: {msg} | {p_seq}... | E={energy:.2f}")
            continue

        # Filtro opcional por energía
        if energy_filter is not None:
            min_e, max_e = energy_filter
            if not (min_e <= energy <= max_e):
                rejected_by_energy += 1
                if rejected_by_energy % 100 == 0:
                    print(f"  [INFO] {rejected_by_energy} secuencias rechazadas por filtro de energía ({min_e} a {max_e} kcal/mol)")
                continue

        # Calcular fracción apareada
        frac = fraction_paired(energy, 60.0)

        # Generar imágenes
        seq_id = len(accepted) + 1
        ps_path, png_path = '', ''
        try:
            ps_path, png_path = plot_structure(full_seq, struct, seq_id)
            print(f"[✓ {len(accepted)+1}/{M}] ID={seq_id} E={energy:.2f} θ={frac:.3f} {full_seq[:12]}... PNG={'✓' if png_path else '✗'}")
        except Exception as e:
            print(f"[✓ {len(accepted)+1}/{M}] ID={seq_id} E={energy:.2f} θ={frac:.3f} {full_seq[:12]}... PNG=✗ (Error: {e})")

        rec = {
            'id': seq_id,
            'seq': full_seq,
            'struct': struct,
            'energy': energy,
            'frac': frac,
            'ps': ps_path,
            'png': png_path
        }
        accepted.append(rec)

    if len(accepted) < M:
        print(f"\n⚠️  Advertencia: {len(accepted)}/{M} secuencias generadas en {attempts} intentos.")
        if energy_filter:
            print(f"    {rejected_by_energy} rechazadas por filtro de energía.")
    else:
        print(f"\n✅ {len(accepted)} secuencias válidas en {attempts} intentos.")
        if energy_filter and rejected_by_energy > 0:
            print(f"   ({rejected_by_energy} rechazadas por filtro de energía)")
    return accepted

# --- Guardar archivos ---
def save_vienna(filename: str, records: List[Dict]):
    with open(filename, 'w') as f:
        for r in records:
            f.write(r['seq'] + '\n')
            f.write(f"{r['struct']} ({r['energy']:.2f})\n")
    print(f"✅ Vienna: {filename}")

def save_csv_summary(filename: str, records: List[Dict]):
    with open(filename, 'w', newline='') as f:
        f.write("id,seq,struct,energy,theta,ps,png\n")
        for r in records:
            f.write(f"{r['id']},{r['seq']},{r['struct']},{r['energy']},{r['frac']:.4f},{r['ps']},{r['png']}\n")
    print(f"✅ CSV: {filename}")

def select_most_stable(records: List[Dict], top_k: int = 5):
    return sorted(records, key=lambda x: x['energy'])[:top_k]

def select_closest_to_equilibrium(records: List[Dict], top_k: int = 5):
    """Selecciona las secuencias con θ más cercano a 0.5 (equilibrio)"""
    return sorted(records, key=lambda x: abs(x['frac'] - 0.5))[:top_k]

# --- CLI principal ---
def main():
    print("=" * 70)
    print("  Generador P(14)-Q(4)-R(14)-S(21) + Validación ViennaRNA 2.7")
    print("=" * 70)

    try:
        M = int(input("\nIngresa M (número de secuencias a generar): ").strip())
    except:
        print("❌ Entrada inválida.")
        return

    # Preguntar si quiere filtro de energía
    use_filter = input("¿Aplicar filtro de energía? (s/n, default=n): ").strip().lower()
    energy_filter = None
    if use_filter == 's':
        try:
            min_e = float(input("  Energía mínima (kcal/mol, ej: -5): ").strip())
            max_e = float(input("  Energía máxima (kcal/mol, ej: 5): ").strip())
            energy_filter = (min_e, max_e)
            print(f"  ✓ Filtro aplicado: {min_e} a {max_e} kcal/mol")
        except:
            print("  ✗ Valores inválidos, sin filtro")

    # Verificar herramientas
    missing = []
    if not shutil.which('RNAfold'): missing.append('RNAfold')
    if not shutil.which('RNAplot'): missing.append('RNAplot')
    if missing:
        print(f"❌ Herramientas faltantes: {', '.join(missing)}")
        return

    if not shutil.which('gs'):
        print("⚠️  Ghostscript (gs) no encontrado. Solo se generarán .ps\n")

    print(f"\n🔬 Generando {M} secuencias válidas (longitud={MIN_LEN})...\n")

    records = generate_M_sequences(M, energy_filter=energy_filter)
    if not records:
        print("❌ No se generaron secuencias válidas.")
        return

    # Guardar resultados
    save_vienna('resultados.vienna', records)
    save_csv_summary('resultados_summary.csv', records)

    # Ranking por estabilidad
    top_stable = select_most_stable(records, top_k=min(5, len(records)))
    print("\n" + "=" * 70)
    print("🏆 TOP 5 ESTRUCTURAS MÁS ESTABLES (energía libre de Gibbs)")
    print("=" * 70)
    for i, t in enumerate(top_stable, 1):
        png_status = "✓" if t['png'] else "✗"
        print(f"{i}. ID={t['id']:3d} | E={t['energy']:6.2f} kcal/mol | θ={t['frac']:.3f} | {t['seq'][:15]}... | PNG={png_status}")

    # Ranking por equilibrio (θ ~ 0.5)
    if len(records) >= 5:
        top_eq = select_closest_to_equilibrium(records, top_k=5)
        print("\n" + "=" * 70)
        print("⚖️  TOP 5 ESTRUCTURAS MÁS CERCANAS AL EQUILIBRIO (θ ≈ 0.5)")
        print("=" * 70)
        for i, t in enumerate(top_eq, 1):
            png_status = "✓" if t['png'] else "✗"
            print(f"{i}. ID={t['id']:3d} | θ={t['frac']:.3f} | E={t['energy']:6.2f} kcal/mol | {t['seq'][:15]}... | PNG={png_status}")

    png_count = sum(1 for r in records if r['png'])
    print(f"\n📊 Resumen: {len(records)} secuencias | {png_count} imágenes PNG generadas")
    print(f"📁 Archivos en: plots/ | resultados.vienna | resultados_summary.csv")
    print("=" * 70)

if __name__ == "__main__":
    main()
# Out:
# ======================================================================
#   Generador P(14)-Q(4)-R(14)-S(21) + Validación ViennaRNA 2.7
# ======================================================================
#
# Ingresa M (número de secuencias a generar): 5
# ¿Aplicar filtro de energía? (s/n, default=n): s
#   Energía mínima (kcal/mol, ej: -5): -5
#   Energía máxima (kcal/mol, ej: 5): 5
#   ✓ Filtro aplicado: -5.0 a 5.0 kcal/mol
#
# 🔬 Generando 5 secuencias válidas (longitud=53)...
#
# [✓ 1/5] ID=1 E=-4.41 θ=0.999 AATATTAGAATT... PNG=✓
# [RECHAZADA] intento 228: Pares extra detectados (6). | CCCCTGTGGGAAAG... | E=-20.87
# [RECHAZADA] intento 231: Pares faltantes del stem (1). | TTCCAACAGAGAGC... | E=-15.87
# [RECHAZADA] intento 234: Pares extra detectados (5). | GGTCCGAGAGGCCG... | E=-22.31
# [RECHAZADA] intento 235: Pares extra detectados (3). | ATAGATGTCCTCTC... | E=-13.76
# [RECHAZADA] intento 236: Pares extra detectados (4). | AACGGTACGTCACA... | E=-15.21
# [RECHAZADA] intento 240: Pares extra detectados (4). | GCACGAAGACTGCA... | E=-18.53
# [RECHAZADA] intento 243: Pares extra detectados (5). | AGTAGAAACCAATG... | E=-13.37
# [RECHAZADA] intento 244: Pares extra detectados (4). | ACGCCTAAGTATCC... | E=-14.73
# [RECHAZADA] intento 249: Pares extra detectados (4). | TAATCTAAAGTCTC... | E=-11.64
# [RECHAZADA] intento 254: Pares extra detectados (5). | GGTCAGGTAGAGGG... | E=-20.53
# [RECHAZADA] intento 255: Pares faltantes del stem (1). | TTGTGAGCACTTCA... | E=-14.44
# [RECHAZADA] intento 257: Pares extra detectados (4). | TACATTAAAGCAGT... | E=-12.88
# [RECHAZADA] intento 258: Pares extra detectados (3). | CTTCAGTACTGCGT... | E=-15.80
# [RECHAZADA] intento 261: Pares extra detectados (6). | ATAGATGATCTGGT... | E=-14.17
# [RECHAZADA] intento 262: Pares extra detectados (7). | TTTTAGTCCCAAGC... | E=-14.29
# [RECHAZADA] intento 271: Pares extra detectados (5). | GTCAGCAACGGACA... | E=-17.95
# [RECHAZADA] intento 272: Pares extra detectados (4). | TTAATTGTCCGTGA... | E=-12.88
# [RECHAZADA] intento 273: Pares extra detectados (4). | GAAATGTGATATCT... | E=-12.00
# [RECHAZADA] intento 274: Pares faltantes del stem (1). | TTCGCAATGTCTGA... | E=-13.88
# [RECHAZADA] intento 276: Pares extra detectados (5). | ACGCTACGAAGAGA... | E=-14.40
# [RECHAZADA] intento 278: Pares faltantes del stem (1). | TTTTTCTACACGGT... | E=-11.49
# [RECHAZADA] intento 282: Pares extra detectados (4). | GCCTCTGACCAAAC... | E=-18.27
#   [INFO] 200 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 288: Pares extra detectados (4). | CGTATACAGCCTTC... | E=-17.06
# [RECHAZADA] intento 289: Pares extra detectados (6). | CTCTGGCGAGCGAT... | E=-20.87
# [RECHAZADA] intento 293: Pares extra detectados (5). | AGATGGGGCGACTT... | E=-19.07
# [RECHAZADA] intento 296: Pares extra detectados (4). | AGATTAGACTGGTG... | E=-14.88
# [RECHAZADA] intento 298: Pares extra detectados (4). | ATTGACTGGATGAC... | E=-13.92
# [RECHAZADA] intento 300: Pares extra detectados (5). | GGCCATGGACCAGA... | E=-22.04
# [RECHAZADA] intento 302: Pares extra detectados (6). | CTCCACACGCCGGA... | E=-21.60
# [RECHAZADA] intento 304: Pares extra detectados (3). | CCTGCATGATATTC... | E=-14.22
# [RECHAZADA] intento 309: Pares extra detectados (4). | CTAGACTATCTCGA... | E=-15.98
# [RECHAZADA] intento 943: Pares extra detectados (6). | AGGACAGGGGTGGG... | E=-21.65
# [RECHAZADA] intento 949: Pares extra detectados (4). | GCCGTCATCGGGTC... | E=-22.47
# [RECHAZADA] intento 950: Pares faltantes del stem (1). | TTAGAGGCCAGTAG... | E=-15.33
# [RECHAZADA] intento 964: Pares extra detectados (7). | CGAGGCCGGCTCTT... | E=-21.77
# [RECHAZADA] intento 966: Pares extra detectados (3). | ACGGGTCGTTAAAG... | E=-13.92
# [RECHAZADA] intento 969: Pares extra detectados (3). | CCGCTCACTTTAGC... | E=-16.68
# [RECHAZADA] intento 972: Pares extra detectados (5). | CCACGAACCCCACG... | E=-22.01
# [RECHAZADA] intento 975: Pares extra detectados (7). | TCCAAAGCAGTGTT... | E=-14.96
# [RECHAZADA] intento 982: Pares faltantes del stem (1). | TTTTTTCCGTCTCT... | E=-12.11
# [RECHAZADA] intento 986: Pares faltantes del stem (1). | TTGTCCGGATGGTT... | E=-15.24
# [RECHAZADA] intento 990: Pares extra detectados (7). | CGGAAGTTCGCACA... | E=-20.81
# [RECHAZADA] intento 993: Pares extra detectados (3). | GATGTCCACTCGGT... | E=-17.61
#   [INFO] 700 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 1000: Pares extra detectados (4). | GTCTAAGGTAGGTA... | E=-14.51
# [RECHAZADA] intento 1008: Pares extra detectados (3). | AATTGGATCGAACA... | E=-11.12
# [RECHAZADA] intento 1009: Pares extra detectados (3). | ATTAAGGGACAGCG... | E=-14.48
# [RECHAZADA] intento 1010: Pares extra detectados (6). | TTGATCCAGGCACT... | E=-19.97
# [RECHAZADA] intento 1011: Pares extra detectados (4). | GCATCTCTTGTTTG... | E=-14.38
# [RECHAZADA] intento 1013: Pares extra detectados (6). | TTATCGTACAAGAC... | E=-12.48
# [RECHAZADA] intento 1014: Pares extra detectados (4). | TACGGGTAGAGGAT... | E=-16.02
# [RECHAZADA] intento 1020: Pares extra detectados (4). | CACTCATTTCGCGG... | E=-16.20
# [RECHAZADA] intento 1022: Pares extra detectados (5). | TGGTGGGAATGTGG... | E=-21.94
# [RECHAZADA] intento 1023: Pares faltantes del stem (2). | ATTCTACGGACACG... | E=-13.26
# [RECHAZADA] intento 1028: Pares extra detectados (3). | TCACTAATCCCGTT... | E=-13.18
# [RECHAZADA] intento 1030: Pares extra detectados (4). | AAATCTACCGACAG... | E=-12.55
# [RECHAZADA] intento 1032: Pares extra detectados (5). | GGAGGCTTTCTGAT... | E=-19.55
# [RECHAZADA] intento 1034: Pares extra detectados (4). | AATCCATTTAATGT... | E=-7.17
# [RECHAZADA] intento 1039: Pares extra detectados (5). | GTAACGAACCGGTC... | E=-21.25
# [RECHAZADA] intento 1041: Pares extra detectados (5). | GCAAAAGAACCGAG... | E=-14.79
# [RECHAZADA] intento 1044: Pares extra detectados (4). | CTTAACTGCGCCGC... | E=-17.63
# [RECHAZADA] intento 1045: Pares extra detectados (4). | GATCGATCTGAGCG... | E=-16.31
# [RECHAZADA] intento 1046: Pares extra detectados (3). | GTGACGAAGATAGA... | E=-14.13
# [RECHAZADA] intento 1048: Pares extra detectados (4). | TGATGTTGGCGCTC... | E=-17.71
# [RECHAZADA] intento 1049: Pares extra detectados (6). | CTGGAGCTGGCCAT... | E=-19.56
# [RECHAZADA] intento 1050: Pares extra detectados (5). | TTTTCATGATTGAT... | E=-7.80
# [RECHAZADA] intento 1053: Pares extra detectados (6). | TTAGACGTCAGCAT... | E=-14.61
# [RECHAZADA] intento 1056: Pares extra detectados (4). | AGGTGCGTTCACTC... | E=-16.06
# [RECHAZADA] intento 1057: Pares extra detectados (5). | ACCTCACGACTTTA... | E=-13.24
# [RECHAZADA] intento 1062: Pares extra detectados (4). | ACAGTACTCCTCTC... | E=-19.85
# [RECHAZADA] intento 1064: Pares extra detectados (5). | ATTTTAAAAAATGC... | E=-5.16
# [RECHAZADA] intento 1065: Pares extra detectados (4). | GACTTACATAAGGC... | E=-14.10
# [RECHAZADA] intento 1072: Pares extra detectados (3). | AAAGCCTCCATCGT... | E=-14.41
# [RECHAZADA] intento 1074: Pares extra detectados (5). | AATCGATGTAAAGT... | E=-8.90
# [RECHAZADA] intento 1075: Pares extra detectados (7). | TCACCAGAAGTCCG... | E=-18.72
# [RECHAZADA] intento 1077: Pares extra detectados (5). | TGCACTCGCCAGTC... | E=-19.33
# [RECHAZADA] intento 1081: Pares extra detectados (5). | TGCTGGCCGGGAGT... | E=-22.30
# [RECHAZADA] intento 1085: Pares extra detectados (5). | TCACACGCTTAGCC... | E=-17.41
# [RECHAZADA] intento 1087: Pares extra detectados (4). | ATTAGCCGTGGGCT... | E=-17.65
# [RECHAZADA] intento 1097: Pares extra detectados (4). | ACTGAGAGTCAATA... | E=-11.76
# [RECHAZADA] intento 1098: Pares extra detectados (6). | CCAGAGATCCGATG... | E=-16.36
# [RECHAZADA] intento 1101: Pares faltantes del stem (1). | TTATATCTCCAGTT... | E=-10.29
# [RECHAZADA] intento 1102: Pares extra detectados (6). | ACACACTGGGGTGG... | E=-20.04
# [RECHAZADA] intento 1104: Pares extra detectados (7). | GTCCTGAAGTCCTC... | E=-19.25
# [RECHAZADA] intento 1113: Pares faltantes del stem (1). | TTATGCCGCTTTAA... | E=-12.08
# [RECHAZADA] intento 1118: Pares extra detectados (5). | GGTTACCGCCTTTG... | E=-16.99
# [RECHAZADA] intento 1121: Pares extra detectados (4). | CCCCGACACAATAA... | E=-15.38
# [RECHAZADA] intento 1122: Pares faltantes del stem (1). | TTGAGTCTAAGGAA... | E=-12.25
# [RECHAZADA] intento 1126: Pares extra detectados (4). | GGTAAGTCTGAAAC... | E=-14.20
# [RECHAZADA] intento 1129: Pares extra detectados (5). | CTAGCTAGAGATAA... | E=-15.76
# [RECHAZADA] intento 1130: Pares extra detectados (6). | GATCAGAAACTACC... | E=-17.32
# [RECHAZADA] intento 1133: Pares extra detectados (3). | AGAAGAGTGCAAAT... | E=-11.18
# [RECHAZADA] intento 1135: Pares faltantes del stem (1). | TTATCTGATATCGA... | E=-10.73
# [RECHAZADA] intento 1141: Pares extra detectados (3). | CGGCCCGGTAATGT... | E=-17.77
#   [INFO] 800 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 
# [RECHAZADA] intento 1404: Pares extra detectados (5). | TCTTAACACCTAGT... | E=-12.09
# [RECHAZADA] intento 1409: Pares extra detectados (4). | TCGGAATAACCAAG... | E=-14.48
# [RECHAZADA] intento 1410: Pares extra detectados (5). | TAGCCGACTAGCTA... | E=-17.07
# [RECHAZADA] intento 1413: Pares extra detectados (4). | CCTGCGCCTGACCT... | E=-21.51
# [RECHAZADA] intento 1418: Pares faltantes del stem (1). | TTGTTGCCTCGGCT... | E=-16.92
# [RECHAZADA] intento 1419: Pares faltantes del stem (1). | TTACATATCGCGGG... | E=-14.82
# [RECHAZADA] intento 1421: Pares extra detectados (5). | AAGAGCTCAAGAAA... | E=-15.50
# [RECHAZADA] intento 1427: Pares extra detectados (5). | AACTGGCGATACGT... | E=-14.37
# [RECHAZADA] intento 1428: Pares extra detectados (6). | CCGCGCTCATCCTC... | E=-21.01
# [RECHAZADA] intento 1432: Pares extra detectados (3). | TGCAGGCCCTGTCC... | E=-23.16
# [RECHAZADA] intento 1433: Pares extra detectados (5). | GCGGCTCGTCCCCT... | E=-22.95
# [RECHAZADA] intento 1436: Pares extra detectados (6). | AATCGTTATGGCAT... | E=-10.45
# [RECHAZADA] intento 1438: Pares extra detectados (4). | TTCCATCGAGTGCA... | E=-16.29
# [RECHAZADA] intento 1441: Pares extra detectados (4). | GGGCGGTGGCCTAA... | E=-21.92
# [RECHAZADA] intento 1442: Pares faltantes del stem (1). | TTGGTTGGTAATCT... | E=-11.88
# [RECHAZADA] intento 1446: Pares faltantes del stem (1). | TTGAAGTAGATCGT... | E=-11.37
#   [INFO] 1000 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 1453: Pares faltantes del stem (1). | TTGCCACCTTACCA... | E=-16.71
# [RECHAZADA] intento 1462: Pares extra detectados (5). | TCACCGGAACCAAG... | E=-17.27
# [RECHAZADA] intento 1463: Pares extra detectados (6). | CCGAAGTTTGTCCA... | E=-15.86
# [RECHAZADA] intento 1465: Pares extra detectados (5). | AAACGTACCACCTG... | E=-15.57
# [RECHAZADA] intento 1466: Pares extra detectados (5). | ATGTCAGAACTTGA... | E=-11.79
# [RECHAZADA] intento 1467: Pares extra detectados (5). | GCAGGAACCGGAGG... | E=-21.78
# [RECHAZADA] intento 1470: Pares faltantes del stem (2). | ATTGATTCGTCGGG... | E=-13.92
# [RECHAZADA] intento 1476: Pares extra detectados (5). | AGACGGTGTCGAGA... | E=-20.84
# [RECHAZADA] intento 1480: Pares extra detectados (5). | GGTCATTTACATTC... | E=-11.36
# [RECHAZADA] intento 1486: Pares extra detectados (6). | TAAGCACCTGGCTT... | E=-15.59
# [RECHAZADA] intento 1488: Pares extra detectados (5). | ACTCGGACGGCGTG... | E=-21.62
# [RECHAZADA] intento 1489: Pares faltantes del stem (1). | TTGGGGGATCCGTC... | E=-19.46
# [RECHAZADA] intento 1494: Pares extra detectados (4). | CCCTGGAGGGCTGA... | E=-22.61
# [RECHAZADA] intento 1498: Pares extra detectados (5). | GAGTTCGCTCTGTA... | E=-15.95
# [RECHAZADA] intento 1507: Pares extra detectados (4). | GAATGTACCCTCTC... | E=-15.68
secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 1600: Pares extra detectados (6). | AGCGCGTAGTGCGG... | E=-20.04
# [RECHAZADA] intento 1606: Pares extra detectados (3). | CTAAATTTCACTCC... | E=-11.07
# [RECHAZADA] intento 1607: Pares extra detectados (3). | CCAAGGTAGAGGAG... | E=-17.77
# [RECHAZADA] intento 1608: Pares extra detectados (6). | CACCGGGGAGTCCA... | E=-24.41
# [RECHAZADA] intento 1611: Pares extra detectados (6). | CTGGATGGACACAC... | E=-18.60
# [RECHAZADA] intento 1616: Pares faltantes del stem (1). | TTGTATTCCTTCGT... | E=-11.31
# [RECHAZADA] intento 1618: Pares extra detectados (4). | ATTCGGATAATTAT... | E=-7.91
# [RECHAZADA] intento 1621: Pares extra detectados (3). | GACAGCCGGCAAAG... | E=-18.83
# [RECHAZADA] intento 1623: Pares extra detectados (5). | ACGGCTTCGATGTA... | E=-15.17
# [RECHAZADA] intento 1625: Pares faltantes del stem (1). | TTAAAGTTGGCTAT... | E=-10.74
# [RECHAZADA] intento 1629: Pares extra detectados (4). | TGTTCGCAATTCGC... | E=-16.37
# [RECHAZADA] intento 1635: Pares extra detectados (5). | TATCCGTCGAGTCG... | E=-15.71
# [RECHAZADA] intento 1649: Pares extra detectados (4). | GACAGTCCGCAAAT... | E=-16.02
# [RECHAZADA] intento 1651: Pares extra detectados (3). | TTAAGGCAGCCCGA... | E=-20.19
# [RECHAZADA] intento 1655: Pares extra detectados (4). | GGGAGACTGCCCGT... | E=-21.27
# [RECHAZADA] intento 1666: Pares faltantes del stem (1). | TTTCATCGTAGGGG... | E=-15.58
# [RECHAZADA] intento 1667: Pares extra detectados (5). | CGGTGTTAATGCAA... | E=-13.54
# [RECHAZADA] intento 1670: Pares faltantes del stem (1). | TTAAATCCCCGGTA... | E=-14.45
# [RECHAZADA] intento 1676: Pares extra detectados (4). | CAAGTGCCACTAAA... | E=-13.83
# [RECHAZADA] intento 1677: Pares extra detectados (5). | AATCCAGTGCAACG... | E=-13.99
# [RECHAZADA] intento 1679: Pares extra detectados (4). | TCTCCCGAAGATAA... | E=-14.54
# [RECHAZADA] intento 1682: Pares faltantes del stem (1). | TTCTCTTACTACAG... | E=-11.73
# [RECHAZADA] intento 1683: Pares extra detectados (6). | TCTCTCGTGTGCCA... | E=-17.14
# [RECHAZADA] intento 1692: Pares extra detectados (4). | AAGTGTTTTAGCCA... | E=-11.71
# [RECHAZADA] intento 1694: Pares extra detectados (4). | GCTGCAGCCGGGAC... | E=-23.81
# [RECHAZADA] intento 1696: Pares extra detectados (4). | GTCATGCCCATGTC... | E=-17.15
# [RECHAZADA] intento 1697: Pares extra detectados (4). | TATACCAGTCGGGC... | E=-19.30
# [RECHAZADA] intento 1702: Pares extra detectados (6). | GCGAGATACGATAG... | E=-16.71
# [RECHAZADA] intento 1706: Pares faltantes del stem (1). | TTAGGTATGGGTAC... | E=-14.30
# [RECHAZADA] intento 1708: Pares faltantes del stem (1). | TTGCTTAATCGGCC... | E=-14.75
# [RECHAZADA] intento 1709: Pares extra detectados (3). | ACATCATCCGCCCG... | E=-17.71
# [RECHAZADA] intento 1714: Pares extra detectados (4). | CTTAGCCGGCTTTC... | E=-15.53
# [RECHAZADA] intento 1715: Pares extra detectados (6). | CTTGTACCCCGTCT... | E=-16.13
# [RECHAZADA] intento 1727: Pares extra detectados (4). | GTGGCAAAGGCAGG... | E=-19.23
# [RECHAZADA] intento 1728: Pares faltantes del stem (2). | ATTTTATAGTACGA... | E=-8.10
# [RECHAZADA] intento 1730: Pares extra detectados (3). | ACAGCTAGGTGATC... | E=-15.14
# [RECHAZADA] intento 1732: Pares extra detectados (4). | GAACGGTCCTGGTC... | E=-18.62
# [RECHAZADA] intento 1733: Pares extra detectados (4). | CTTTTGGAGTAATG... | E=-11.74
#   [INFO] 1200 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 1735: Pares extra detectados (3). | GTAGTGGATCACTG... | E=-15.36
# [RECHAZADA] intento 1739: Pares extra detectados (5). | CTGTTACTTCGACC... | E=-14.09
# [RECHAZADA] intento 1743: Pares faltantes del stem (2). | ATTAGGGCGTACGC... | E=-16.39
# [RECHAZADA] intento 1746: Pares extra detectados (5). | AATAGTTCGGCAGA... | E=-15.31
# [RECHAZADA] intento 1747: Pares extra detectados (3). | AGGAGGCCTCCAAC... | E=-20.20
# [RECHAZADA] intento 1749: Pares extra detectados (5). | CAGTTAGCAGACCT... | E=-16.48
# [RECHAZADA] intento 1750: Pares extra detectados (4). | GCGCCCACCTTGAT... | E=-19.35
# [RECHAZADA] intento 1751: Pares extra detectados (6). | GTGCTCTTATATCG... | E=-13.91
# [RECHAZADA] intento 1752: Pares extra detectados (5). | ATTGTTTCGTGACA... | E=-13.03
# [RECHAZADA] intento 1753: Pares extra detectados (3). | AGAGATTATATGAG... | E=-11.33
# [RECHAZADA] intento 1759: Pares extra detectados (3). | CACCAAAGGGCTCC... | E=-19.23
# [RECHAZADA] intento 1761: Pares extra detectados (3). | TCGAGCTATATCTC... | E=-13.68
# [RECHAZADA] intento 1762: Pares extra detectados (4). | CATGTCAGTCACTG... | E=-15.10
# [RECHAZADA] intento 1769: Pares faltantes del stem (1). | TTAGTCACCCGTTT... | E=-13.24
# [RECHAZADA] intento 1771: Pares extra detectados (4). | CTAATGCTAATGGG... | E=-15.29
# [RECHAZADA] intento 1772: Pares extra detectados (7). | GATTGTCAGCATGC... | E=-19.45
# ...
# [RECHAZADA] intento 3984: Pares extra detectados (4). | CTAGAGAGTTCACG... | E=-13.93
# [RECHAZADA] intento 3986: Pares extra detectados (5). | TCGTAGGTCGGACG... | E=-19.92
# [RECHAZADA] intento 3989: Pares extra detectados (4). | CCCCGCCTGCTTAC... | E=-20.43
# [RECHAZADA] intento 3990: Pares extra detectados (4). | CGAACATGTCACTG... | E=-15.73
# [RECHAZADA] intento 3997: Pares faltantes del stem (1). | TTCGGGTCGTATGT... | E=-14.72
# [RECHAZADA] intento 3999: Pares extra detectados (5). | CCTTTTAAAGCGTG... | E=-13.40
# [RECHAZADA] intento 4000: Pares extra detectados (7). | ATGTTGTCATCTAT... | E=-10.88
# [RECHAZADA] intento 4006: Pares extra detectados (7). | GCATGATGTCGATT... | E=-20.48
# [RECHAZADA] intento 4008: Pares extra detectados (6). | TAAATGATTCCAGT... | E=-10.36
# [RECHAZADA] intento 4012: Pares extra detectados (7). | ATACGGGGTCTTAA... | E=-14.47
# [RECHAZADA] intento 4015: Pares extra detectados (3). | GGTTTACGGACCCA... | E=-18.94
# [RECHAZADA] intento 4016: Pares extra detectados (4). | CTTTGCATCAGCTG... | E=-16.55
# [RECHAZADA] intento 4020: Pares extra detectados (6). | AGTGTATACTAACC... | E=-14.68
# [RECHAZADA] intento 4023: Pares faltantes del stem (2). | ATTGCACGCAACTC... | E=-14.15
# [RECHAZADA] intento 4024: Pares faltantes del stem (1). | TTCTCTGATAGTAA... | E=-11.19
# [RECHAZADA] intento 4025: Pares extra detectados (5). | GAGAGATACTATCC... | E=-16.61
# [RECHAZADA] intento 4029: Pares extra detectados (3). | TAAGCCATGGAGGA... | E=-17.64
# [RECHAZADA] intento 4031: Pares extra detectados (4). | ATCGAGTGCATGCC... | E=-18.70
# [RECHAZADA] intento 4033: Pares extra detectados (4). | TCCGGTCATCTCCA... | E=-18.64
#   [INFO] 2800 secuencias rechazadas por filtro de energía (-5.0 a 5.0 kcal/mol)
# [RECHAZADA] intento 4040: Pares extra detectados (3). | GGCACGAGGCATAT... | E=-17.36
# [RECHAZADA] intento 4042: Pares extra detectados (4). | TTCTGTCCGTAAGA... | E=-14.88
# [RECHAZADA] intento 4043: Pares extra detectados (5). | TACGATGGTGCAAT... | E=-15.34
# [RECHAZADA] intento 4046: Pares extra detectados (7). | TCTGTCCAACGTTG... | E=-16.39
# [RECHAZADA] intento 4047: Pares extra detectados (5). | ATACGCGGTCAGCG... | E=-17.73
# [RECHAZADA] intento 4055: Pares extra detectados (6). | ACAGAACACTCGCT... | E=-14.58
# [RECHAZADA] intento 4058: Pares extra detectados (4). | CTACGAATTCTCTC... | E=-12.27
# [RECHAZADA] intento 4059: Pares extra detectados (5). | CGTTGCTGTAGGAA... | E=-15.92
# [RECHAZADA] intento 4061: Pares extra detectados (5). | TAGGGACACGGTAC... | E=-18.19
# [RECHAZADA] intento 4062: Pares extra detectados (7). | CCGATGAGCGAGGG... | E=-21.66
# [RECHAZADA] intento 4069: Pares extra detectados (3). | TAGGCCGGTCGGGT... | E=-20.57
# [RECHAZADA] intento 4070: Pares faltantes del stem (2). | ATTGACTGGCAGGC... | E=-17.22
# [RECHAZADA] intento 4078: Pares extra detectados (5). | GTCTGTTATGACTT... | E=-13.03
# [RECHAZADA] intento 4079: Pares extra detectados (8). | AGTGGGGCAGAATC... | E=-17.98
# [RECHAZADA] intento 4081: Pares extra detectados (6). | GCAGGAGTTCGTGC... | E=-20.57
# [RECHAZADA] intento 4082: Pares extra detectados (3). | AAGCGTACAGTTGG... | E=-14.57
# [RECHAZADA] intento 4085: Pares extra detectados (5). | ACAGATGTTCCAGT... | E=-15.79
# [RECHAZADA] intento 4496: Pares extra detectados (6). | GCAACTTTTGAAAT... | E=-9.34
# [RECHAZADA] intento 4499: Pares extra detectados (5). | GACACAGATTTCAA... | E=-12.95
# [RECHAZADA] intento 4500: Pares faltantes del stem (1). | TTTTAGGGGCTACA... | E=-14.94
# [RECHAZADA] intento 4505: Pares extra detectados (5). | CGGTTTAACACGCG... | E=-14.93
# [RECHAZADA] intento 4506: Pares extra detectados (4). | TAGACAGGTATCGA... | E=-15.09
# [RECHAZADA] intento 4509: Pares faltantes del stem (1). | TTCTTCTCGCGTTG... | E=-14.54
# [RECHAZADA] intento 4513: Pares extra detectados (4). | ACAAGCGTGATCCG... | E=-16.84
# [RECHAZADA] intento 4515: Pares extra detectados (4). | CTAGACGAATCGTT... | E=-14.17
# [RECHAZADA] intento 4518: Pares extra detectados (5). | AGGGACAATAGTCC... | E=-16.12
# [✓ 5/5] ID=5 E=-4.29 θ=0.998 TAATAATTAAAC... PNG=✓
#
# ✅ 5 secuencias válidas en 4522 intentos.
#    (3135 rechazadas por filtro de energía)
# ✅ Vienna: resultados.vienna
# ✅ CSV: resultados_summary.csv
#
# ======================================================================
# 🏆 TOP 5 ESTRUCTURAS MÁS ESTABLES (energía libre de Gibbs)
# ======================================================================
# 1. ID=  2 | E= -4.89 kcal/mol | θ=0.999 | AACTATTTTTCAATA... | PNG=✓
# 2. ID=  1 | E= -4.41 kcal/mol | θ=0.999 | AATATTAGAATTAAA... | PNG=✓
# 3. ID=  5 | E= -4.29 kcal/mol | θ=0.998 | TAATAATTAAACTAT... | PNG=✓
# 4. ID=  3 | E= -4.19 kcal/mol | θ=0.998 | AATTTCAAAAATAAG... | PNG=✓
# 5. ID=  4 | E= -3.92 kcal/mol | θ=0.997 | AAGAAATATTATATC... | PNG=✓
#
# ======================================================================
# ⚖️  TOP 5 ESTRUCTURAS MÁS CERCANAS AL EQUILIBRIO (θ ≈ 0.5)
# ======================================================================
# 1. ID=  4 | θ=0.997 | E= -3.92 kcal/mol | AAGAAATATTATATC... | PNG=✓
# 2. ID=  3 | θ=0.998 | E= -4.19 kcal/mol | AATTTCAAAAATAAG... | PNG=✓
# 3. ID=  5 | θ=0.998 | E= -4.29 kcal/mol | TAATAATTAAACTAT... | PNG=✓
# 4. ID=  1 | θ=0.999 | E= -4.41 kcal/mol | AATATTAGAATTAAA... | PNG=✓
# 5. ID=  2 | θ=0.999 | E= -4.89 kcal/mol | AACTATTTTTCAATA... | PNG=✓
#
# 📊 Resumen: 5 secuencias | 5 imágenes PNG generadas
# 📁 Archivos en: plots/ | resultados.vienna | resultados_summary.csv
# ======================================================================

# %%
import shutil

# Comprime la carpeta 'plots' en un archivo ZIP
shutil.make_archive("plots", 'zip', "plots")

print("✅ Carpeta 'plots/' comprimida como 'plots.zip'")
# Out:
# ✅ Carpeta 'plots/' comprimida como 'plots.zip'

# %% [markdown]
# ________________________________________________________

# %% [markdown]
# _________________________________________________________________

# %% [markdown]
# _______________________________________________________________
