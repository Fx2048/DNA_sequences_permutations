# %%
# Instala conda (si no está instalado)
# !pip install -q condacolab
import condacolab
condacolab.install()

# Instala ViennaRNA desde conda-forge
# !conda install -c bioconda viennarna -y

# Verifica instalación
# !RNAfold --version
# !RNAplot --version
# Out:
# ✨🍰✨ Everything looks OK!
# Channels:
#  - bioconda
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# RNAfold 2.7.0
# RNAplot 2.7.0

# %%
# !apt-get install viennarna -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package viennarna

# %%
# !sudo apt update
# !sudo apt install ghostscript
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://cli.github.com/packages stable InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 38 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ghostscript is already the newest version (9.55.0~dfsg1-0ubuntu5.13).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# !gs --version
# Out:
# 9.55.0

# %%
#!/usr/bin/env python3
"""
gen_vienna_hairpins.py v2.6

Genera M secuencias P(14)-Q(4)-R(14)-S(21), valida con ViennaRNA (RNAfold),
rechaza secuencias que formen más de 1 horquilla o donde Q empareje con P/R,
genera imágenes (RNAplot + gs), guarda resultados en formato Vienna.

Compatible con ViennaRNA 2.7.0

Requisitos:
 - RNAfold y RNAplot en PATH (ViennaRNA 2.7+)
 - Ghostscript 'gs' (para PNG)
"""

import random
import subprocess
import shutil
import os
import sys
import glob
from typing import Set, Tuple, List, Dict

# Parámetros del esquema (fijos según tu especificación)
P = 14
Q = 4
R = 14
S = 21
MIN_LEN = P + Q + R + S  # 53

# Random seed para reproducibilidad (opcional)
random.seed()

# Complemento ADN
COMP = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

def complement_base(b: str) -> str:
    return COMP.get(b.upper(), 'N')

def complement_reverse(seq: str) -> str:
    return ''.join(complement_base(c) for c in reversed(seq))

def random_seq(length: int) -> str:
    return ''.join(random.choice(['A','C','G','T']) for _ in range(length))

# --- Dot-bracket -> pares (i,j) ---
def pairs_from_dotbracket(db: str) -> Set[Tuple[int,int]]:
    stack = []
    pairs = set()
    for i, ch in enumerate(db):
        if ch == '(':
            stack.append(i)
        elif ch == ')':
            if not stack:
                continue
            j = stack.pop()
            a, b = (j, i) if j < i else (i, j)
            pairs.add((a,b))
    return pairs

# --- Pares diseñados P<->R (índices 0-based) ---
def designed_pairs_indices(P_len: int, Q_len: int, R_len: int) -> Set[Tuple[int,int]]:
    """
    Para i in [0..P_len-1] -> j = P_len + Q_len + (R_len-1 - i)
    """
    pairs = set()
    for i in range(min(P_len, R_len)):
        j = P_len + Q_len + (R_len - 1 - i)
        a, b = (i, j) if i < j else (j, i)
        pairs.add((a,b))
    return pairs

DESIGNED_PAIRS = designed_pairs_indices(P, Q, R)

# --- Ejecutar RNAfold --noPS sobre una secuencia y parsear salida ---
def evaluate_with_rnafold(seq: str) -> Tuple[str, float]:
    if not shutil.which('RNAfold'):
        raise RuntimeError("RNAfold no encontrado en PATH.")
    try:
        proc = subprocess.run(
            ['RNAfold', '--noPS'],
            input=seq.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True
        )
        out = proc.stdout.decode().strip().splitlines()
        if len(out) < 2:
            raise RuntimeError("Salida inesperada de RNAfold")

        struct_line = out[1].strip()
        idx = struct_line.rfind('(')
        if idx == -1:
            parts = struct_line.split()
            struct = parts[0]
            energy = float(parts[-1].strip('()'))
        else:
            struct = struct_line[:idx].strip()
            energy = float(struct_line[idx:].strip('() ').replace(',', '.'))
        return struct, energy
    except subprocess.CalledProcessError as e:
        raise RuntimeError(f"Error RNAfold: {e.stderr.decode()}")

# --- Generar imagen usando RNAplot (v2.7 compatible) y convertir a PNG ---
def plot_structure(seq: str, struct: str, seq_idx: int) -> Tuple[str, str]:
    """
    Genera archivos seq_{idx}_ss.ps y seq_{idx}.png en carpeta plots/
    Compatible con RNAplot 2.7.0 (sin opciones -o)
    Retorna (ps_path, png_path)
    """
    if not shutil.which('RNAplot'):
        raise RuntimeError("RNAplot no encontrado en PATH.")

    # Verificar que longitudes coincidan
    if len(seq) != len(struct):
        raise RuntimeError(f"Longitudes no coinciden: seq={len(seq)}, struct={len(struct)}")

    # Nombres de archivos finales
    base = f"seq_{seq_idx}"
    ps_path = os.path.join('plots', f"{base}_ss.ps")
    png_path = os.path.join('plots', f"{base}.png")

    input_text = f"{seq}\n{struct}\n"

    # Guardar directorio original
    original_dir = os.getcwd()

    try:
        # Cambiar a directorio plots para que RNAplot genere archivos ahí
        os.chdir('plots')

        # Limpiar archivos PS/EPS antiguos en el directorio
        for old_file in glob.glob('*.ps') + glob.glob('*.eps'):
            try:
                os.remove(old_file)
            except:
                pass

        # RNAplot 2.7 lee stdin y genera rna_ss.ps
        proc = subprocess.run(
            ["RNAplot"],
            input=input_text,
            text=True,
            capture_output=True
        )

        # Verificar si hubo error
        if proc.returncode != 0:
            raise RuntimeError(f"RNAplot falló: {proc.stderr}")

        # Esperar un momento para que el archivo se escriba completamente
        import time
        time.sleep(0.1)

        # Buscar archivo .ps o .eps generado (intentar varios nombres comunes)
        possible_names = ['rna_ss.ps', 'rna.ps', 'rna.eps', 'ss.ps']
        generated_ps = None

        for name in possible_names:
            if os.path.exists(name):
                generated_ps = name
                break

        # Si no encontramos ninguno, buscar cualquier .ps/.eps
        if not generated_ps:
            ps_files = glob.glob('*.ps') + glob.glob('*.eps')
            if ps_files:
                generated_ps = ps_files[0]

        if not generated_ps:
            # Debug: listar todos los archivos
            all_files = os.listdir('.')
            raise RuntimeError(f"RNAplot no generó archivo PS/EPS. Archivos en plots/: {all_files}. stderr: {proc.stderr}")

        # Archivo encontrado
        final_ps_name = f"{base}_ss.ps"

        # Renombrar si es necesario
        if generated_ps != final_ps_name:
            if os.path.exists(final_ps_name):
                os.remove(final_ps_name)
            os.rename(generated_ps, final_ps_name)

        ps_path = os.path.join(os.getcwd(), final_ps_name)

        # Convertir a PNG con Ghostscript
        png_created = ''
        if shutil.which('gs'):
            try:
                png_name = f"{base}.png"
                # Ghostscript necesita -dEPSCrop para archivos EPS
                result = subprocess.run([
                    "gs", "-dSAFER", "-dBATCH", "-dNOPAUSE", "-dQUIET",
                    "-dEPSCrop",  # Importante para archivos EPS
                    "-sDEVICE=pngalpha", "-r300",  # Aumentar resolución a 300 DPI
                    f"-sOutputFile={png_name}", final_ps_name
                ], capture_output=True)

                if result.returncode != 0:
                    raise RuntimeError(f"Ghostscript error: {result.stderr.decode()}")

                if os.path.exists(png_name):
                    png_created = os.path.join(os.getcwd(), png_name)
                else:
                    raise RuntimeError(f"PNG no se generó: {png_name}")

            except Exception as e:
                print(f"  ⚠️  Ghostscript falló para seq_{seq_idx}: {e}")
        else:
            print(f"  ⚠️  'gs' no encontrado; solo .ps disponible para seq_{seq_idx}")

        return ps_path, png_created

    except Exception as e:
        raise RuntimeError(f"Error en plot_structure: {e}")
    finally:
        # Volver al directorio original
        os.chdir(original_dir)

# --- Validación de estructura ---
def analyze_structure_validity(struct: str, seq_len: int, P_len: int, Q_len: int, R_len: int) -> Tuple[bool, str]:
    """
    Retorna (valid, message). valid=True si:
      - Los pares coinciden exactamente con DESIGNED_PAIRS
      - Q no forma pares con P o R
    """
    pred_pairs = pairs_from_dotbracket(struct)
    extra_pairs = pred_pairs - DESIGNED_PAIRS
    missing_pairs = DESIGNED_PAIRS - pred_pairs

    q_start = P_len
    q_end = P_len + Q_len - 1
    q_pairs = [p for p in pred_pairs if (q_start <= p[0] <= q_end) or (q_start <= p[1] <= q_end)]

    if extra_pairs:
        return False, f"Pares extra detectados ({len(extra_pairs)})."
    if missing_pairs:
        return False, f"Pares faltantes del stem ({len(missing_pairs)})."
    if q_pairs:
        return False, f"Loop Q presenta emparejamientos no permitidos."
    return True, "Válida"

# --- Generador principal ---
def generate_M_sequences(M: int, max_attempts=10000) -> List[Dict]:
    """
    Genera hasta M secuencias válidas.
    Retorna lista de dicts: id, seq, struct, energy, ps, png
    """
    if M <= 0:
        raise ValueError("M debe ser > 0")

    os.makedirs("plots", exist_ok=True)
    accepted = []
    seen = set()
    attempts = 0

    while len(accepted) < M and attempts < max_attempts:
        attempts += 1

        # Generar secuencia P-Q-R-S
        p_seq = random_seq(P)
        q_seq = random_seq(Q) if Q > 0 else ''
        r_seq = complement_reverse(p_seq)
        s_seq = random_seq(S) if S > 0 else ''
        full_seq = p_seq + q_seq + r_seq + s_seq

        if full_seq in seen:
            continue
        seen.add(full_seq)

        # Evaluar con RNAfold
        try:
            struct, energy = evaluate_with_rnafold(full_seq)
        except Exception as e:
            print(f"❌ Error RNAfold: {e}")
            continue

        # Validar estructura
        valid, msg = analyze_structure_validity(struct, len(full_seq), P, Q, R)
        if not valid:
            print(f"[RECHAZADA] intento {attempts}: {msg} | {p_seq}... | E={energy:.2f}")
            continue

        # Generar imágenes
        seq_id = len(accepted) + 1
        ps_path, png_path = '', ''
        try:
            ps_path, png_path = plot_structure(full_seq, struct, seq_id)
            print(f"[✓ {len(accepted)+1}/{M}] ID={seq_id} E={energy:.2f} {full_seq[:12]}... PNG={'✓' if png_path else '✗'}")
        except Exception as e:
            print(f"[✓ {len(accepted)+1}/{M}] ID={seq_id} E={energy:.2f} {full_seq[:12]}... PNG=✗ (Error: {e})")

        rec = {
            'id': seq_id,
            'seq': full_seq,
            'struct': struct,
            'energy': energy,
            'ps': ps_path,
            'png': png_path
        }
        accepted.append(rec)

    if len(accepted) < M:
        print(f"\n⚠️  Advertencia: {len(accepted)}/{M} secuencias generadas en {attempts} intentos.")
    else:
        print(f"\n✅ {len(accepted)} secuencias válidas en {attempts} intentos.")
    return accepted

# --- Guardar archivos ---
def save_vienna(filename: str, records: List[Dict]):
    with open(filename, 'w') as f:
        for r in records:
            f.write(r['seq'] + '\n')
            f.write(f"{r['struct']} ({r['energy']:.2f})\n")
    print(f"✅ Vienna: {filename}")

def save_csv_summary(filename: str, records: List[Dict]):
    with open(filename, 'w', newline='') as f:
        f.write("id,seq,struct,energy,ps,png\n")
        for r in records:
            f.write(f"{r['id']},{r['seq']},{r['struct']},{r['energy']},{r['ps']},{r['png']}\n")
    print(f"✅ CSV: {filename}")

def select_most_stable(records: List[Dict], top_k: int = 5):
    return sorted(records, key=lambda x: x['energy'])[:top_k]

# --- CLI principal ---
def main():
    print("=" * 70)
    print("  Generador P(14)-Q(4)-R(14)-S(21) + Validación ViennaRNA 2.7")
    print("=" * 70)

    try:
        M = int(input("\nIngresa M (número de secuencias a generar): ").strip())
    except:
        print("❌ Entrada inválida.")
        return

    # Verificar herramientas
    missing = []
    if not shutil.which('RNAfold'): missing.append('RNAfold')
    if not shutil.which('RNAplot'): missing.append('RNAplot')
    if missing:
        print(f"❌ Herramientas faltantes: {', '.join(missing)}")
        return

    if not shutil.which('gs'):
        print("⚠️  Ghostscript (gs) no encontrado. Solo se generarán .ps\n")

    print(f"\n🔬 Generando {M} secuencias válidas (longitud={MIN_LEN})...\n")

    records = generate_M_sequences(M)
    if not records:
        print("❌ No se generaron secuencias válidas.")
        return

    # Guardar resultados
    save_vienna('resultados.vienna', records)
    save_csv_summary('resultados_summary.csv', records)

    # Ranking por estabilidad
    top = select_most_stable(records, top_k=min(5, len(records)))
    print("\n" + "=" * 70)
    print("🏆 TOP ESTRUCTURAS MÁS ESTABLES (energía libre de Gibbs)")
    print("=" * 70)
    for i, t in enumerate(top, 1):
        png_status = "✓" if t['png'] else "✗"
        print(f"{i}. ID={t['id']:3d} | E={t['energy']:6.2f} kcal/mol | {t['seq'][:15]}... | PNG={png_status}")

    png_count = sum(1 for r in records if r['png'])
    print(f"\n📊 Resumen: {len(records)} secuencias | {png_count} imágenes PNG generadas")
    print(f"📁 Archivos en: plots/ | resultados.vienna | resultados_summary.csv")
    print("=" * 70)

if __name__ == "__main__":
    main()
# Out:
# ======================================================================
#   Generador P(14)-Q(4)-R(14)-S(21) + Validación ViennaRNA 2.7
# ======================================================================
#
# Ingresa M (número de secuencias a generar): 200
#
# 🔬 Generando 200 secuencias válidas (longitud=53)...
#
# [RECHAZADA] intento 1: Pares extra detectados (4). | ATAGAAGGTAACCG... | E=-24.40
# [RECHAZADA] intento 2: Pares extra detectados (4). | AGGTATGTAGTGAG... | E=-23.80
# [RECHAZADA] intento 3: Pares extra detectados (4). | CGGATAGTGATCGA... | E=-26.20
# [RECHAZADA] intento 4: Pares extra detectados (6). | GACCTGAAGGGATG... | E=-31.20
# [RECHAZADA] intento 5: Pares extra detectados (3). | GCGACGACCCGCAG... | E=-32.60
# [RECHAZADA] intento 6: Pares extra detectados (7). | TTTACATGCGAGTA... | E=-26.20
# [RECHAZADA] intento 7: Pares extra detectados (3). | ATACTAGTTAACGC... | E=-20.50
# [✓ 1/200] ID=1 E=-22.20 CCGGCGATGTTT... PNG=✓
# [RECHAZADA] intento 9: Pares extra detectados (4). | CGGCCAGTAGCTAC... | E=-28.20
# [RECHAZADA] intento 10: Pares extra detectados (5). | GGACTATACAAACG... | E=-26.30
# [RECHAZADA] intento 11: Pares extra detectados (5). | ACTCTCTCCGTTCG... | E=-32.30
# [✓ 2/200] ID=2 E=-25.80 TCCGATGGTGGC... PNG=✓
# [RECHAZADA] intento 13: Pares extra detectados (4). | ACCGCATGTCAACC... | E=-27.10
# [RECHAZADA] intento 14: Pares extra detectados (8). | TGCTGCTGGACGAC... | E=-30.20
# [✓ 3/200] ID=3 E=-20.40 TATCTCAAGGGT... PNG=✓
# [RECHAZADA] intento 16: Pares extra detectados (3). | AAACCGTCACAACG... | E=-23.10
# [✓ 4/200] ID=4 E=-23.60 CTACAAGGCATC... PNG=✓
# [RECHAZADA] intento 18: Pares extra detectados (6). | CAGATCGAGATTTT... | E=-21.00
# [✓ 5/200] ID=5 E=-15.90 AGAAAATTAACA... PNG=✓
# [RECHAZADA] intento 20: Pares extra detectados (3). | CCGAGGTAACGAAG... | E=-26.20
# [RECHAZADA] intento 21: Pares extra detectados (6). | GGTCAAGCACACAA... | E=-27.90
# [RECHAZADA] intento 22: Pares extra detectados (6). | TTCATCAGCTGTAC... | E=-28.00
# [RECHAZADA] intento 23: Pares extra detectados (4). | AAATCACGTTCTAG... | E=-23.60
# [RECHAZADA] intento 24: Pares extra detectados (6). | TGAGATACATGCAA... | E=-23.00
# [✓ 6/200] ID=6 E=-21.70 TCCTAAAGATCG... PNG=✓
# [RECHAZADA] intento 26: Pares extra detectados (3). | AACTCCCGGTGTAT... | E=-25.00
# [RECHAZADA] intento 27: Pares extra detectados (2). | ATGTAAATCGAGCT... | E=-19.40
# [RECHAZADA] intento 28: Pares extra detectados (3). | CGTGCCATCCACTT... | E=-25.50
# [RECHAZADA] intento 29: Pares extra detectados (7). | GCTACAGATGAGCC... | E=-28.60
# [✓ 7/200] ID=7 E=-22.90 CGGTCATTCAGA... PNG=✓
# [RECHAZADA] intento 31: Pares extra detectados (4). | TGAGTCAAACTGTA... | E=-23.60
# [RECHAZADA] intento 32: Pares extra detectados (5). | CCTCCTTCTGAAGG... | E=-28.00
# [RECHAZADA] intento 33: Pares extra detectados (4). | GCATAGTAGCTGTT... | E=-24.90
# [RECHAZADA] intento 34: Pares extra detectados (4). | GTTTCTGACAAGAC... | E=-23.40
# [✓ 8/200] ID=8 E=-13.40 AAATTATCTATC... PNG=✓
# [✓ 9/200] ID=9 E=-23.80 TTACCTCGGACT... PNG=✓
# [RECHAZADA] intento 37: Pares extra detectados (2). | TTCGGTGACGGGGT... | E=-29.00
# [✓ 10/200] ID=10 E=-22.00 TATGCTCATGTT... PNG=✓
# [RECHAZADA] intento 39: Pares extra detectados (4). | CTTTGCAATAGTCG... | E=-24.00
# [✓ 11/200] ID=11 E=-19.90 ATGAGAGCACTA... PNG=✓
# [RECHAZADA] intento 41: Pares extra detectados (3). | AGACGATCGACTCA... | E=-26.00
# [RECHAZADA] intento 42: Pares extra detectados (5). | TTTGGCGGATCAGG... | E=-27.50
# [✓ 12/200] ID=12 E=-29.70 GGGCTGAGGATG... PNG=✓
# [RECHAZADA] intento 44: Pares extra detectados (5). | ACACCAAGCCCCAT... | E=-27.60
# [✓ 13/200] ID=13 E=-20.70 CCATACGTCTTT... PNG=✓
# [RECHAZADA] intento 46: Pares extra detectados (6). | ACTTGTGACTATAT... | E=-23.10
# [✓ 14/200] ID=14 E=-26.40 TCTCACCGACCA... PNG=✓
# [RECHAZADA] intento 48: Pares extra detectados (5). | CATCAACTGGAAAT... | E=-23.50
# [RECHAZADA] intento 49: Pares extra detectados (7). | TCAACCAGTGCTTA... | E=-26.40
# [RECHAZADA] intento 50: Pares extra detectados (2). | CTTAATCGCAGCCC... | E=-26.00
# [✓ 15/200] ID=15 E=-27.40 TCGTCCTGGTCG... PNG=✓
# [RECHAZADA] intento 52: Pares extra detectados (6). | CGGACTACACGGCG... | E=-32.50
# [RECHAZADA] intento 53: Pares extra detectados (4). | TAGACACTAGTACA... | E=-21.40
# [RECHAZADA] intento 54: Pares extra detectados (3). | AGTAAAAAAGGCCC... | E=-23.30
# [RECHAZADA] intento 55: Pares extra detectados (4). | TATAAAGACCGTTC... | E=-22.60
# [✓ 16/200] ID=16 E=-21.90 CCATTCTTACGT... PNG=✓
# [RECHAZADA] intento 57: Pares extra detectados (5). | AGTTGATTATCTTG... | E=-17.50
# [✓ 17/200] ID=17 E=-22.30 GGTATCTGTTTC... PNG=✓
# [RECHAZADA] intento 59: Pares extra detectados (4). | GTAGCCCGCGACTC... | E=-34.20
# [✓ 18/200] ID=18 E=-19.50 TTACGAAAGACT... PNG=✓
# [RECHAZADA] intento 61: Pares extra detectados (6). | GCGGGTCGTCAAGG... | E=-31.70
# [RECHAZADA] intento 62: Pares extra detectados (5). | TAGGCGTGCCAAGT... | E=-26.30
# [✓ 19/200] ID=19 E=-21.60 GGCTTTATATCT... PNG=✓
# [RECHAZADA] intento 64: Pares extra detectados (3). | ATATGGACAGATAC... | E=-23.40
# [RECHAZADA] intento 65: Pares extra detectados (2). | TTGTGAGTAGGGTA... | E=-23.60
# [RECHAZADA] intento 66: Pares extra detectados (2). | TGCCGGATGAGTAA... | E=-25.00
# [RECHAZADA] intento 67: Pares extra detectados (3). | TTACGCATATAAGT... | E=-18.80
# [RECHAZADA] intento 68: Pares extra detectados (3). | CACGGGAGGCGCGC... | E=-37.50
# [RECHAZADA] intento 69: Pares extra detectados (5). | GCACCGGAGGGGAA... | E=-32.90
# [RECHAZADA] intento 70: Pares extra detectados (3). | TCTAAGAGTAGATC... | E=-22.00
# [✓ 20/200] ID=20 E=-27.20 CCCATCCATCGG... PNG=✓
# [✓ 21/200] ID=21 E=-18.90 TACCAATTTGAT... PNG=✓
# [RECHAZADA] intento 73: Pares extra detectados (3). | CCATAGACTTGAAG... | E=-25.90
# [✓ 22/200] ID=22 E=-25.60 ACCCCGAGGTCT... PNG=✓
# [RECHAZADA] intento 75: Pares extra detectados (6). | AGATTTCAGTACCG... | E=-25.10
# [RECHAZADA] intento 76: Pares extra detectados (5). | GACTCTGTCGCTGG... | E=-29.40
# [RECHAZADA] intento 77: Pares extra detectados (5). | AGGCGTAGTTACAC... | E=-26.60
# [RECHAZADA] intento 78: Pares extra detectados (6). | ATTTGCGAGTTCTC... | E=-24.50
# [RECHAZADA] intento 79: Pares extra detectados (4). | TGAGCTAAAACCCA... | E=-26.20
# [✓ 23/200] ID=23 E=-22.50 GTGGATTACAAC... PNG=✓
# [✓ 24/200] ID=24 E=-25.10 ACTGCTTCTGAA... PNG=✓
# [✓ 25/200] ID=25 E=-21.70 ACATTTGCTGAC... PNG=✓
# [RECHAZADA] intento 83: Pares extra detectados (3). | GCCGGCGTTAGGTC... | E=-30.80
# [✓ 26/200] ID=26 E=-21.40 TACTCACTCATG... PNG=✓
# [RECHAZADA] intento 85: Pares extra detectados (2). | ACGCCCCGCAAGGA... | E=-29.20
# [RECHAZADA] intento 86: Pares extra detectados (7). | GTAAAGCCGGGTTA... | E=-27.90
# [RECHAZADA] intento 87: Pares extra detectados (6). | ACCGCGTATGCTCA... | E=-28.90
# [RECHAZADA] intento 88: Pares extra detectados (4). | GGGGGGAAGTGGCA... | E=-34.40
# [RECHAZADA] intento 89: Pares extra detectados (4). | AAGGTTGGGACATT... | E=-23.70
# [RECHAZADA] intento 90: Pares extra detectados (4). | TAAACGTGAGAAAA... | E=-18.50
# [RECHAZADA] intento 91: Pares extra detectados (5). | TTAAATTGGGCTAA... | E=-26.70
# [✓ 27/200] ID=27 E=-29.40 GTGTTGCGGCCT... PNG=✓
# [RECHAZADA] intento 93: Pares extra detectados (7). | GTCTCATTGACCGC... | E=-32.90
# [✓ 28/200] ID=28 E=-24.00 TACTGCTGGTAC... PNG=✓
# [✓ 29/200] ID=29 E=-26.70 TGCGGGTATAGG... PNG=✓
# [✓ 30/200] ID=30 E=-25.20 GATTACAGCCAT... PNG=✓
# [RECHAZADA] intento 97: Pares extra detectados (2). | CGCGGTTTTCAACG... | E=-23.30
# [RECHAZADA] intento 98: Pares extra detectados (4). | AGCGCGATGAGGTT... | E=-30.50
# [✓ 31/200] ID=31 E=-22.90 TGAAATCACACG... PNG=✓
# [RECHAZADA] intento 100: Pares extra detectados (4). | TTGAAGCGCAATGT... | E=-22.60
# [✓ 32/200] ID=32 E=-23.40 CACATAGAACCA... PNG=✓
# [✓ 33/200] ID=33 E=-27.70 ACCAGCGCGCAC... PNG=✓
# [RECHAZADA] intento 103: Pares extra detectados (6). | ATTCCTAATACCGT... | E=-24.30
# [RECHAZADA] intento 104: Pares extra detectados (4). | CCCGTACTATGGTG... | E=-26.70
# [RECHAZADA] intento 105: Pares extra detectados (4). | GCGGCGTTGGGGAC... | E=-31.50
# [RECHAZADA] intento 106: Pares extra detectados (4). | CTGAACCTGGACCG... | E=-30.60
# [✓ 34/200] ID=34 E=-25.60 CTGCCTTCATCG... PNG=✓
# [RECHAZADA] intento 108: Pares extra detectados (4). | CTGAGCCCCTGGAC... | E=-35.10
# [RECHAZADA] intento 109: Pares extra detectados (4). | GCTTTCCGAAAGCA... | E=-23.20
# [RECHAZADA] intento 110: Pares extra detectados (3). | GAACTGGAGGCCGG... | E=-30.90
# [RECHAZADA] intento 111: Pares extra detectados (8). | AATCACTGGTCCCG... | E=-27.70
# [RECHAZADA] intento 112: Pares extra detectados (5). | TCTGGACCTACGGA... | E=-29.50
# [RECHAZADA] intento 113: Pares extra detectados (3). | CGTGGTGTACCTAA... | E=-24.00
# [RECHAZADA] intento 114: Pares extra detectados (3). | TGACAAGCCTTGCC... | E=-26.50
# [✓ 35/200] ID=35 E=-19.90 AACATGGTTTCA... PNG=✓
# [RECHAZADA] intento 116: Pares extra detectados (3). | GGTACCGATCAAAG... | E=-25.60
# [RECHAZADA] intento 117: Pares extra detectados (4). | TTTTTCCGGAGGTA... | E=-22.70
# [✓ 36/200] ID=36 E=-19.30 TCAAATGAACAC... PNG=✓
# [RECHAZADA] intento 119: Pares extra detectados (4). | CTATTCGCGAGCTT... | E=-25.40
# [RECHAZADA] intento 120: Pares extra detectados (4). | ACACGATCGCCAAT... | E=-23.90
# [RECHAZADA] intento 121: Pares extra detectados (6). | TCTGAAAAACTACT... | E=-22.20
# [RECHAZADA] intento 122: Pares extra detectados (3). | TTATTGGATCTTAC... | E=-17.90
# [RECHAZADA] intento 123: Pares extra detectados (3). | CATTAGTTCAGCCT... | E=-24.50
# [RECHAZADA] intento 124: Pares extra detectados (5). | AGATCGGCCTTCGC... | E=-28.80
# [RECHAZADA] intento 125: Pares extra detectados (4). | GGAAGTATGACTCT... | E=-25.70
# [RECHAZADA] intento 126: Pares extra detectados (5). | ACGGGTGACAATGT... | E=-24.40
# [RECHAZADA] intento 127: Pares extra detectados (3). | TAGCCCTATACGTA... | E=-24.40
# [RECHAZADA] intento 128: Pares extra detectados (3). | TCAACTACGACGGT... | E=-24.20
# [RECHAZADA] intento 129: Pares extra detectados (5). | CTGTGATTGCATTA... | E=-20.40
# [RECHAZADA] intento 130: Pares extra detectados (6). | GCGGTGGAGCAGAC... | E=-31.10
# [RECHAZADA] intento 131: Pares extra detectados (3). | CTTGCACTGGCGCA... | E=-30.50
# [RECHAZADA] intento 132: Pares extra detectados (4). | GAACATGCTACCAT... | E=-25.10
# [✓ 37/200] ID=37 E=-26.10 CCTTCGGGCTCA... PNG=✓
# [RECHAZADA] intento 134: Pares extra detectados (4). | ACTTTTGAATGGTG... | E=-19.70
# [RECHAZADA] intento 135: Pares extra detectados (3). | CGCACCGAAGGACC... | E=-31.80
# [RECHAZADA] intento 136: Pares extra detectados (5). | TTCACTTCACGGAT... | E=-24.20
# [✓ 38/200] ID=38 E=-24.80 TCTACATTGTCC... PNG=✓
# [RECHAZADA] intento 138: Pares extra detectados (8). | ACTGTAGCTAACAA... | E=-21.60
# [✓ 39/200] ID=39 E=-26.00 CACGGACGCCAA... PNG=✓
# [RECHAZADA] intento 140: Pares extra detectados (5). | ATTCGCGCGTGCAA... | E=-31.00
# [RECHAZADA] intento 141: Pares extra detectados (3). | TGGTAAGCTCGTGA... | E=-24.90
# [RECHAZADA] intento 142: Pares extra detectados (5). | GTGCCGTTGCGCAG... | E=-29.40
# [RECHAZADA] intento 143: Pares extra detectados (6). | CGCCAACCCGCGCC... | E=-38.20
# [RECHAZADA] intento 144: Pares extra detectados (2). | GCGGATGTAAGTTC... | E=-24.80
# [RECHAZADA] intento 145: Pares extra detectados (2). | CAGGGTAATCTTGA... | E=-23.30
# [✓ 40/200] ID=40 E=-23.70 TCCCAAACCGAA... PNG=✓
# [RECHAZADA] intento 147: Pares extra detectados (2). | CGGACGATAGACAA... | E=-24.40
# [RECHAZADA] intento 148: Pares extra detectados (3). | GCCGGTGTCGACCT... | E=-33.00
# [✓ 41/200] ID=41 E=-24.80 CCTCGTCAGCTT... PNG=✓
# [RECHAZADA] intento 150: Pares extra detectados (3). | TGTCTTGTTCCCAG... | E=-23.80
# [RECHAZADA] intento 151: Pares extra detectados (4). | GAAAGCTCTTCGCT... | E=-25.50
# [✓ 42/200] ID=42 E=-25.80 CAGCAGATGCGA... PNG=✓
# [RECHAZADA] intento 153: Pares extra detectados (3). | TTTTCCATATTCCT... | E=-18.30
# [RECHAZADA] intento 154: Pares extra detectados (6). | GACGACCGAACAGG... | E=-29.80
# [RECHAZADA] intento 155: Pares extra detectados (4). | GTTACAAAATCTAA... | E=-16.40
# [RECHAZADA] intento 156: Pares extra detectados (5). | CGACGTGGCCTCTG... | E=-29.40
# [RECHAZADA] intento 157: Pares extra detectados (5). | TCGCGTTCAACGAA... | E=-25.30
# [✓ 43/200] ID=43 E=-24.50 CCGTGCCACAGT... PNG=✓
# [RECHAZADA] intento 159: Pares extra detectados (4). | CCCAGGCTCTAACG... | E=-29.40
# [RECHAZADA] intento 160: Pares extra detectados (4). | CCTAGTGGACAGTC... | E=-28.70
# [✓ 44/200] ID=44 E=-26.00 GGTGATAGAAGC... PNG=✓
# [RECHAZADA] intento 162: Pares extra detectados (3). | AATCGACCAGGTTA... | E=-25.70
# [RECHAZADA] intento 163: Pares extra detectados (2). | GTTATGCTTATGGC... | E=-23.40
# [RECHAZADA] intento 164: Pares extra detectados (4). | CGCAATTTTTACCG... | E=-21.90
# [✓ 45/200] ID=45 E=-24.00 AAGCCCTGGATC... PNG=✓
# [RECHAZADA] intento 166: Pares extra detectados (6). | GGCGGTCCTGTCCT... | E=-35.50
# [RECHAZADA] intento 167: Pares extra detectados (3). | CTCCCCCTCCCAGT... | E=-31.60
# [RECHAZADA] intento 168: Pares extra detectados (5). | TCAGTACATCAAGC... | E=-25.70
# [✓ 46/200] ID=46 E=-19.30 TCTTAACCGCAT... PNG=✓
# [✓ 47/200] ID=47 E=-25.40 GGCGCCAATAGT... PNG=✓
# [RECHAZADA] intento 171: Pares extra detectados (5). | TGATGCGCTGTGCC... | E=-31.10
# [RECHAZADA] intento 172: Pares extra detectados (3). | TTGAGCAAAACGGC... | E=-26.30
# [RECHAZADA] intento 173: Pares extra detectados (6). | GAGAACGCACTTCA... | E=-37.80
# [RECHAZADA] intento 174: Pares extra detectados (4). | AGCATTGAAGTCGG... | E=-25.50
# [✓ 48/200] ID=48 E=-30.50 GCGGGCGTGTCC... PNG=✓
# [✓ 49/200] ID=49 E=-27.70 GCACGGTAGACG... PNG=✓
# [✓ 50/200] ID=50 E=-23.40 TCCACAACTAGC... PNG=✓
# [✓ 51/200] ID=51 E=-23.90 TGACACAGAAAG... PNG=✓
# [RECHAZADA] intento 179: Pares extra detectados (5). | GTCGAAAACGGCGA... | E=-30.70
# [RECHAZADA] intento 180: Pares extra detectados (4). | TGCAGCAACAGCAT... | E=-25.50
# [RECHAZADA] intento 181: Pares extra detectados (5). | GGTGGTGGCCGGTA... | E=-32.40
# [RECHAZADA] intento 182: Pares extra detectados (3). | CACCAGCGAGTATT... | E=-24.40
# [RECHAZADA] intento 183: Pares extra detectados (2). | GCCGCGCTGCGTTT... | E=-28.40
# [RECHAZADA] intento 184: Pares extra detectados (5). | TAAAGCCGAACGTG... | E=-24.30
# [✓ 52/200] ID=52 E=-26.30 TGTCACCGCTAG... PNG=✓
# [RECHAZADA] intento 186: Pares extra detectados (3). | CACGCCACTCAGAC... | E=-30.70
# [✓ 53/200] ID=53 E=-22.20 TCCATTTGCCTC... PNG=✓
# [✓ 54/200] ID=54 E=-27.20 TCAGCAGTCGGG... PNG=✓
# [RECHAZADA] intento 189: Pares extra detectados (4). | CCTTTCCCCCGCAC... | E=-29.80
# [✓ 55/200] ID=55 E=-27.20 CACGGGCAGTGG... PNG=✓
# [RECHAZADA] intento 191: Pares extra detectados (6). | CATTCCGATAAAAG... | E=-21.30
# [RECHAZADA] intento 192: Pares extra detectados (3). | CTCTGCTCAAGCAG... | E=-27.60
# [RECHAZADA] intento 193: Pares extra detectados (4). | CACGAAGTTACAGT... | E=-23.80
# [RECHAZADA] intento 194: Pares extra detectados (4). | CAATCGGGGTGATG... | E=-27.90
# [RECHAZADA] intento 195: Pares extra detectados (4). | GAGTGTTTTTTCAA... | E=-23.80
# [RECHAZADA] intento 196: Pares extra detectados (2). | ATATTCCACCAGCC... | E=-26.20
# [✓ 56/200] ID=56 E=-29.40 AGCCACTAGGCC... PNG=✓
# [✓ 57/200] ID=57 E=-13.40 GTTACATAATAA... PNG=✓
# [✓ 58/200] ID=58 E=-27.00 ACCCTGCACACG... PNG=✓
# [RECHAZADA] intento 200: Pares extra detectados (7). | GTTCTCAGAAGAGT... | E=-25.00
# [✓ 59/200] ID=59 E=-24.70 TTGAGCGAGGTG... PNG=✓
# [RECHAZADA] intento 202: Pares extra detectados (5). | CGTAACATGATGGG... | E=-23.30
# [RECHAZADA] intento 203: Pares extra detectados (4). | TAGACATGGATCTG... | E=-26.00
# [RECHAZADA] intento 204: Pares extra detectados (3). | GTAGGATATAAATC... | E=-19.90
# [RECHAZADA] intento 205: Pares extra detectados (4). | CTGAAAATAGGGAG... | E=-24.50
# [✓ 60/200] ID=60 E=-24.50 GATGGACGAGTC... PNG=✓
# [RECHAZADA] intento 207: Pares extra detectados (3). | ACCTTCCGCTCACG... | E=-27.30
# [RECHAZADA] intento 208: Pares extra detectados (6). | CACAATGTAAGCAT... | E=-26.20
# [✓ 61/200] ID=61 E=-19.20 ATTAGACAGCTT... PNG=✓
# [✓ 62/200] ID=62 E=-16.80 TTCCTCATAAAA... PNG=✓
# [RECHAZADA] intento 211: Pares extra detectados (7). | CTTGCTGCAAGTTG... | E=-23.90
# [RECHAZADA] intento 212: Pares extra detectados (6). | AGGGTGGGTCACGA... | E=-31.30
# [RECHAZADA] intento 213: Pares extra detectados (6). | GCCGCGGATATAGA... | E=-29.30
# [RECHAZADA] intento 214: Pares extra detectados (3). | ACGTGCCTCGCCTT... | E=-27.30
# [✓ 63/200] ID=63 E=-20.80 ATTTATCGGTGG... PNG=✓
# [RECHAZADA] intento 216: Pares extra detectados (6). | TACCCTGGGCTACC... | E=-33.10
# [RECHAZADA] intento 217: Pares extra detectados (2). | GACCGCGGGACCGA... | E=-32.40
# [RECHAZADA] intento 218: Pares extra detectados (5). | CCCACCGACAGCGA... | E=-30.60
# [RECHAZADA] intento 219: Pares extra detectados (6). | AATAGCTCACAATA... | E=-20.20
# [RECHAZADA] intento 220: Pares extra detectados (4). | GACGTTGCTGCCGT... | E=-27.80
# [✓ 64/200] ID=64 E=-19.70 TCAAACTCCTCA... PNG=✓
# [✓ 65/200] ID=65 E=-18.60 TTCCATTCATTA... PNG=✓
# [RECHAZADA] intento 223: Pares extra detectados (5). | CGATGACCGGCAGC... | E=-32.20
# [RECHAZADA] intento 224: Pares extra detectados (5). | GTACCGGCCCTCCC... | E=-35.50
# [RECHAZADA] intento 225: Pares extra detectados (5). | CCCAGGTCTGCTGG... | E=-31.60
# [RECHAZADA] intento 226: Pares extra detectados (3). | CTCCGTGCCCCAAA... | E=-28.20
# [✓ 66/200] ID=66 E=-26.60 GCATCTCACCAC... PNG=✓
# [✓ 67/200] ID=67 E=-26.70 GGGATGCGTAGG... PNG=✓
# [RECHAZADA] intento 229: Pares extra detectados (4). | GGTGACACGGCCTT... | E=-32.80
# [RECHAZADA] intento 230: Pares extra detectados (4). | AATCTAATAAGAAA... | E=-16.50
# [✓ 68/200] ID=68 E=-26.30 GGACCAAACTGG... PNG=✓
# [RECHAZADA] intento 232: Pares extra detectados (4). | TCTGTCTTCGTAGG... | E=-27.00
# [RECHAZADA] intento 233: Pares extra detectados (4). | TGTACCCAGAATTC... | E=-24.50
# [RECHAZADA] intento 234: Pares extra detectados (4). | TCTCGCCTGGACAG... | E=-31.10
# [✓ 69/200] ID=69 E=-27.80 TCGGCGGAGTCG... PNG=✓
# [RECHAZADA] intento 236: Pares extra detectados (5). | AGCTATCAAACGCT... | E=-25.20
# [✓ 70/200] ID=70 E=-20.20 GTAATACCGTAT... PNG=✓
# [✓ 71/200] ID=71 E=-17.50 ACAGAGTAAATT... PNG=✓
# [RECHAZADA] intento 239: Pares extra detectados (2). | GAAGATCTTTGTAG... | E=-20.40
# [✓ 72/200] ID=72 E=-29.10 CGTGACGCCGTC... PNG=✓
# [✓ 73/200] ID=73 E=-21.90 GTAGTGTACTTG... PNG=✓
# [RECHAZADA] intento 242: Pares extra detectados (4). | TTCAAAAAATCCCA... | E=-18.40
# [RECHAZADA] intento 243: Pares extra detectados (2). | CGAGATCCCTCTGC... | E=-28.80
# [RECHAZADA] intento 244: Pares extra detectados (5). | GAAATGCATGAGGA... | E=-26.30
# [RECHAZADA] intento 245: Pares extra detectados (4). | AGCAAAGTTCAGGT... | E=-22.40
# [RECHAZADA] intento 246: Pares extra detectados (4). | AAAAGCTGATTCTT... | E=-20.50
# [✓ 74/200] ID=74 E=-30.40 GGTGAGGGGGAA... PNG=✓
# [RECHAZADA] intento 248: Pares extra detectados (5). | CTCCATGTTAGTAC... | E=-28.00
# [RECHAZADA] intento 249: Pares extra detectados (5). | GGGATTTGAATAGC... | E=-24.80
# [RECHAZADA] intento 250: Pares extra detectados (4). | TTAAGTGGCGTCTA... | E=-24.50
# [RECHAZADA] intento 251: Pares extra detectados (7). | TTCGAATTATTTAC... | E=-19.50
# [RECHAZADA] intento 252: Pares extra detectados (4). | GCTCTTCAACACTC... | E=-28.60
# [RECHAZADA] intento 253: Pares extra detectados (5). | CAGAGGGTAAATGT... | E=-24.00
# [RECHAZADA] intento 254: Pares extra detectados (4). | CCGCTCATCCACAG... | E=-28.70
# [RECHAZADA] intento 255: Pares extra detectados (6). | GCTCCGGTGAGTTT... | E=-29.90
# [✓ 75/200] ID=75 E=-21.90 TATTGAAGGAGG... PNG=✓
# [RECHAZADA] intento 257: Pares extra detectados (4). | CTGGATCCCCGTGG... | E=-31.10
# [✓ 76/200] ID=76 E=-26.70 GGGCGATGACAC... PNG=✓
# [RECHAZADA] intento 259: Pares extra detectados (5). | GTCACTCACTAGGG... | E=-32.10
# [✓ 77/200] ID=77 E=-24.40 TCGCATCTAGCC... PNG=✓
# [✓ 78/200] ID=78 E=-24.90 GGTCGTTTAGCC... PNG=✓
# [RECHAZADA] intento 262: Pares extra detectados (3). | GTCTTGAGGACTAA... | E=-23.00
# [RECHAZADA] intento 263: Pares extra detectados (6). | ACACAGTCACTAGC... | E=-28.40
# [RECHAZADA] intento 264: Pares extra detectados (6). | CGTTGTATTGTGAT... | E=-19.50
# [RECHAZADA] intento 265: Pares extra detectados (2). | CGTTTGTTCCAGTA... | E=-21.00
# [RECHAZADA] intento 266: Pares extra detectados (5). | AACGAACGACCAAA... | E=-22.40
# [RECHAZADA] intento 267: Pares extra detectados (4). | TGCCGTAAGATACT... | E=-25.50
# [✓ 79/200] ID=79 E=-21.40 TATGCGTGCACA... PNG=✓
# [RECHAZADA] intento 269: Pares extra detectados (4). | ATACGGAGACATAC... | E=-22.10
# [RECHAZADA] intento 270: Pares extra detectados (4). | TTTAAATTAGACTT... | E=-15.50
# [✓ 80/200] ID=80 E=-27.00 TCTGGACGCCAT... PNG=✓
# [RECHAZADA] intento 272: Pares extra detectados (4). | CCACTTTTATATCT... | E=-19.10
# [✓ 81/200] ID=81 E=-20.10 TGCCACCATATT... PNG=✓
# [RECHAZADA] intento 274: Pares extra detectados (4). | GACCGCCGGCTGCA... | E=-33.70
# [RECHAZADA] intento 275: Pares extra detectados (3). | ACGCTACGGATACG... | E=-25.90
# [RECHAZADA] intento 276: Pares extra detectados (3). | CCAACTACCCCCCG... | E=-30.30
# [✓ 82/200] ID=82 E=-27.70 GTACCTGCCGTC... PNG=✓
# [RECHAZADA] intento 278: Pares extra detectados (4). | AGTTATTTGCGCTC... | E=-21.90
# [RECHAZADA] intento 279: Pares extra detectados (5). | GAGTCCTGTATTTT... | E=-26.60
# [✓ 83/200] ID=83 E=-25.50 TTCTCGGCCACT... PNG=✓
# [✓ 84/200] ID=84 E=-13.10 TAAAGTATATTT... PNG=✓
# [RECHAZADA] intento 282: Pares extra detectados (3). | CCAATCCTTTCACG... | E=-24.00
# [RECHAZADA] intento 283: Pares extra detectados (4). | CTCTTAGCCGGCTA... | E=-26.20
# [RECHAZADA] intento 284: Pares extra detectados (4). | GTGCTTGAACCTGC... | E=-28.00
# [RECHAZADA] intento 285: Pares extra detectados (5). | TTATACTGAGTGGA... | E=-24.50
# [RECHAZADA] intento 286: Pares extra detectados (2). | CGTTCGAAGCAGGC... | E=-28.00
# [✓ 85/200] ID=85 E=-21.40 AGAGTCGTTTCA... PNG=✓
# [RECHAZADA] intento 288: Pares extra detectados (5). | GATCGGTTGAAGTT... | E=-25.00
# [RECHAZADA] intento 289: Pares extra detectados (6). | CGCTAGGGGATGGG... | E=-32.60
# [RECHAZADA] intento 290: Pares extra detectados (5). | CTATGACCACTACG... | E=-23.40
# [RECHAZADA] intento 291: Pares extra detectados (5). | TCCCGCCACAAAAT... | E=-25.70
# [RECHAZADA] intento 292: Pares extra detectados (3). | CATATTACTTCTAT... | E=-19.00
# [RECHAZADA] intento 293: Pares extra detectados (4). | ACCTGTATAGAGTT... | E=-21.50
# [RECHAZADA] intento 294: Pares extra detectados (4). | AACTCTCATCCTAA... | E=-21.70
# [RECHAZADA] intento 295: Pares extra detectados (4). | GACACTGAAGGTCC... | E=-28.70
# [RECHAZADA] intento 296: Pares extra detectados (7). | TCAAGTCTACACGT... | E=-26.00
# [RECHAZADA] intento 297: Pares extra detectados (3). | CAGCTTTTGGTATC... | E=-25.50
# [RECHAZADA] intento 298: Pares extra detectados (4). | ATCATGAGTTTGCG... | E=-23.80
# [RECHAZADA] intento 299: Pares extra detectados (4). | TTTGTTTTCTCATC... | E=-17.10
# [RECHAZADA] intento 300: Pares extra detectados (4). | GATACGTAAGTGTC... | E=-22.30
# [✓ 86/200] ID=86 E=-28.20 AACTGGGGTCGG... PNG=✓
# [RECHAZADA] intento 302: Pares extra detectados (4). | CAAGGAAGACACCC... | E=-28.40
# [✓ 87/200] ID=87 E=-23.00 TACGCCGTTCAG... PNG=✓
# [✓ 88/200] ID=88 E=-24.00 GCACCTTACGAG... PNG=✓
# [✓ 89/200] ID=89 E=-19.30 CCTTTACATACC... PNG=✓
# [✓ 90/200] ID=90 E=-22.10 GAGCATGCAAAC... PNG=✓
# [RECHAZADA] intento 307: Pares extra detectados (5). | ATAGCCCGCTTGTA... | E=-25.50
# [RECHAZADA] intento 308: Pares extra detectados (3). | ATCTAAAGAGGAAA... | E=-19.90
# [RECHAZADA] intento 309: Pares extra detectados (2). | TAAGTATACGACAT... | E=-19.20
# [RECHAZADA] intento 310: Pares extra detectados (7). | TGGGCTCCCTGGCA... | E=-39.10
# [RECHAZADA] intento 311: Pares extra detectados (4). | AGCACGTCTCAAGT... | E=-25.20
# [RECHAZADA] intento 312: Pares extra detectados (5). | GTGGGTGATACGCG... | E=-28.30
# [✓ 91/200] ID=91 E=-24.20 GACGCTGAATAG... PNG=✓
# [RECHAZADA] intento 314: Pares extra detectados (6). | GATTGGATGCGAGG... | E=-28.40
# [✓ 92/200] ID=92 E=-18.50 CTTTGAAATACG... PNG=✓
# [✓ 93/200] ID=93 E=-24.40 CACCCTATCTGT... PNG=✓
# [✓ 94/200] ID=94 E=-21.20 GTGGTGCATAAA... PNG=✓
# [✓ 95/200] ID=95 E=-20.70 GAAGTACTTAGC... PNG=✓
# [RECHAZADA] intento 319: Pares extra detectados (3). | AATAGAGCTAATAT... | E=-18.10
# [✓ 96/200] ID=96 E=-23.10 ATGAGACATCTG... PNG=✓
# [RECHAZADA] intento 321: Pares extra detectados (5). | GGAGCAGGCACCCG... | E=-34.90
# [RECHAZADA] intento 322: Pares extra detectados (3). | CGACTCAGTCCGTG... | E=-27.20
# [RECHAZADA] intento 323: Pares extra detectados (4). | TGTTGTTCGTATGC... | E=-21.60
# [RECHAZADA] intento 324: Pares extra detectados (6). | CGGTATAAGTGTCA... | E=-24.60
# [RECHAZADA] intento 325: Pares extra detectados (3). | GCCTAAGCTAAAAT... | E=-22.20
# [RECHAZADA] intento 326: Pares extra detectados (3). | AACAGCGCCTGTGG... | E=-28.50
# [RECHAZADA] intento 327: Pares extra detectados (5). | AAGTATACAGTCAT... | E=-23.50
# [RECHAZADA] intento 328: Pares extra detectados (4). | TCCACTTAAACGCT... | E=-23.60
# [✓ 97/200] ID=97 E=-26.50 ACCGCGTCGAAA... PNG=✓
# [RECHAZADA] intento 330: Pares extra detectados (4). | GACTCAGAGAAAGC... | E=-28.50
# [RECHAZADA] intento 331: Pares extra detectados (3). | GGGAATCAGGAACG... | E=-27.90
# [RECHAZADA] intento 332: Pares extra detectados (4). | GGTAGGAAAGCCGG... | E=-29.50
# [RECHAZADA] intento 333: Pares extra detectados (4). | GGTCGACCTATGGC... | E=-29.50
# [RECHAZADA] intento 334: Pares extra detectados (6). | ATGGCCTACACCCC... | E=-31.20
# [RECHAZADA] intento 335: Pares extra detectados (3). | ACATATTAGTACAC... | E=-20.00
# [✓ 98/200] ID=98 E=-21.20 ACTGGACCTTTT... PNG=✓
# [RECHAZADA] intento 337: Pares extra detectados (3). | ATGACGTGACTAAA... | E=-19.00
# [✓ 99/200] ID=99 E=-25.10 CTTCTGCGGTAC... PNG=✓
# [RECHAZADA] intento 339: Pares extra detectados (4). | ATTAACTTTGTGGT... | E=-20.20
# [✓ 100/200] ID=100 E=-19.40 TTAATGTCGGTA... PNG=✓
# [RECHAZADA] intento 341: Pares extra detectados (4). | GCACTCACACAAAT... | E=-23.30
# [✓ 101/200] ID=101 E=-18.70 TAATACTAACCG... PNG=✓
# [RECHAZADA] intento 343: Pares extra detectados (5). | TAAGCAAGTTCCAA... | E=-25.90
# [✓ 102/200] ID=102 E=-23.40 GTAACCCGTCTA... PNG=✓
# [RECHAZADA] intento 345: Pares extra detectados (3). | CCTAATACACGCTC... | E=-24.60
# [RECHAZADA] intento 346: Pares extra detectados (4). | GCTCCTGTGAGCGC... | E=-33.30
# [RECHAZADA] intento 347: Pares extra detectados (5). | GGTGATCGGGCCTA... | E=-30.80
# [RECHAZADA] intento 348: Pares extra detectados (5). | TTTAACGGACATCC... | E=-23.30
# [✓ 103/200] ID=103 E=-25.20 CGACTGTGCTAT... PNG=✓
# [RECHAZADA] intento 350: Pares extra detectados (4). | TGTCCGACTAAAAT... | E=-21.50
# [RECHAZADA] intento 351: Pares extra detectados (5). | ATTTGTTAAGTCTT... | E=-16.20
# [RECHAZADA] intento 352: Pares extra detectados (3). | ATAGAACCGTACGG... | E=-23.00
# [RECHAZADA] intento 353: Pares extra detectados (6). | ATCCCCGGGCAGGG... | E=-33.50
# [RECHAZADA] intento 354: Pares extra detectados (5). | GAACCATCTTAGGG... | E=-27.10
# [✓ 104/200] ID=104 E=-25.40 GGAACCAGCTTG... PNG=✓
# [RECHAZADA] intento 356: Pares extra detectados (3). | CGCAAGACCAAACT... | E=-23.00
# [✓ 105/200] ID=105 E=-19.90 CAGTGAATATCG... PNG=✓
# [✓ 106/200] ID=106 E=-28.30 CATCAGAGGACC... PNG=✓
# [RECHAZADA] intento 359: Pares extra detectados (2). | TACCAAAGTCAGGT... | E=-21.90
# [RECHAZADA] intento 360: Pares extra detectados (3). | AACATAGCTTTCTG... | E=-21.80
# [✓ 107/200] ID=107 E=-25.20 ATAGGTGCTGAG... PNG=✓
# [RECHAZADA] intento 362: Pares extra detectados (3). | GCGCTTCTATAGGG... | E=-26.70
# [✓ 108/200] ID=108 E=-21.30 GTGTATTGTCGT... PNG=✓
# [✓ 109/200] ID=109 E=-19.50 CCTAAATAGTTA... PNG=✓
# [RECHAZADA] intento 365: Pares extra detectados (5). | GATACTTTACCGGA... | E=-30.30
# [RECHAZADA] intento 366: Pares extra detectados (3). | ATTGGCGCGTCGCA... | E=-29.60
# [✓ 110/200] ID=110 E=-23.20 CATATTCGTTGG... PNG=✓
# [RECHAZADA] intento 368: Pares extra detectados (5). | TTGTAGTCGTTTGA... | E=-21.80
# [RECHAZADA] intento 369: Pares extra detectados (3). | TAACGCTCTTCACT... | E=-24.10
# [RECHAZADA] intento 370: Pares extra detectados (5). | TAGGGGCCCGTACG... | E=-29.10
# [RECHAZADA] intento 371: Pares extra detectados (6). | CCTCCGGTTTAACC... | E=-26.40
# [RECHAZADA] intento 372: Pares extra detectados (5). | GTTAGGCTTTAAAG... | E=-27.10
# [RECHAZADA] intento 373: Pares extra detectados (5). | ACGCTTTGTATACT... | E=-22.50
# [RECHAZADA] intento 374: Pares extra detectados (6). | TCGTAGCCGGCATG... | E=-29.60
# [RECHAZADA] intento 375: Pares extra detectados (5). | GACTAGTCCTTGAC... | E=-28.10
# [✓ 111/200] ID=111 E=-22.00 TCCAAATTTAGG... PNG=✓
# [RECHAZADA] intento 377: Pares extra detectados (6). | TACGGTCGTCGCAC... | E=-28.50
# [RECHAZADA] intento 378: Pares extra detectados (3). | TTGAGTGCACCGGG... | E=-29.80
# [✓ 112/200] ID=112 E=-21.20 ACTATGCAGTTC... PNG=✓
# [RECHAZADA] intento 380: Pares extra detectados (4). | TTCATCTGAAGGGT... | E=-26.60
# [RECHAZADA] intento 381: Pares extra detectados (3). | TATTCCACGGTGGA... | E=-26.10
# [RECHAZADA] intento 382: Pares extra detectados (2). | GTCATGTAGTACGC... | E=-24.00
# [RECHAZADA] intento 383: Pares extra detectados (5). | TTGCGTAAGGGGAC... | E=-29.50
# [RECHAZADA] intento 384: Pares extra detectados (2). | CAATATTAGCCGAT... | E=-20.20
# [RECHAZADA] intento 385: Pares extra detectados (5). | ACGGGTCCGCTCAG... | E=-33.20
# [RECHAZADA] intento 386: Pares extra detectados (3). | TCAGGTTAGTCATG... | E=-25.80
# [RECHAZADA] intento 387: Pares extra detectados (2). | TTAAGAGCTGGATT... | E=-20.50
# [RECHAZADA] intento 388: Pares extra detectados (4). | GGATTCGATGTGCG... | E=-27.10
# [✓ 113/200] ID=113 E=-13.80 ATATATACATAA... PNG=✓
# [✓ 114/200] ID=114 E=-21.70 TGCTACTGTAAC... PNG=✓
# [RECHAZADA] intento 391: Pares extra detectados (5). | TCCGTCTGTATTCT... | E=-23.40
# [✓ 115/200] ID=115 E=-22.20 CAAGAAGGGATA... PNG=✓
# [RECHAZADA] intento 393: Pares extra detectados (4). | ATTTCATTCCTATG... | E=-17.70
# [RECHAZADA] intento 394: Pares extra detectados (3). | AGGAGTCTACAGGT... | E=-26.20
# [✓ 116/200] ID=116 E=-19.90 TAACACTCGATA... PNG=✓
# [RECHAZADA] intento 396: Pares extra detectados (4). | CAAGCCATTCCGAA... | E=-24.10
# [RECHAZADA] intento 397: Pares extra detectados (4). | TCCTAATGACGATT... | E=-22.00
# [✓ 117/200] ID=117 E=-25.70 AGGTAGGTTGCG... PNG=✓
# [✓ 118/200] ID=118 E=-22.30 CTCGGATTTTGA... PNG=✓
# [✓ 119/200] ID=119 E=-19.40 TATTCAGATTCA... PNG=✓
# [RECHAZADA] intento 401: Pares extra detectados (3). | ATCGCTCCATCCGC... | E=-27.80
# [✓ 120/200] ID=120 E=-24.50 GATGTAACGGCG... PNG=✓
# [RECHAZADA] intento 403: Pares extra detectados (2). | GCGTTGGTACCCGC... | E=-30.60
# [✓ 121/200] ID=121 E=-25.40 TGGGACAGTGGT... PNG=✓
# [RECHAZADA] intento 405: Pares extra detectados (5). | TCTGCGTGGGGCTC... | E=-33.40
# [RECHAZADA] intento 406: Pares extra detectados (4). | ATATGGTTCCACAG... | E=-22.30
# [✓ 122/200] ID=122 E=-27.30 GATCCGCTGGAC... PNG=✓
# [RECHAZADA] intento 408: Pares extra detectados (3). | CCGCGACCTACAGC... | E=-30.00
# [RECHAZADA] intento 409: Pares extra detectados (4). | GGCTCGGTTAGTTG... | E=-27.70
# [RECHAZADA] intento 410: Pares extra detectados (5). | TCTATATGCTTTCG... | E=-22.00
# [✓ 123/200] ID=123 E=-28.20 GGAATTCCCTGG... PNG=✓
# [RECHAZADA] intento 412: Pares extra detectados (3). | CTACGTCATCGCGG... | E=-27.70
# [RECHAZADA] intento 413: Pares extra detectados (5). | AGCGCTAAAACAAA... | E=-20.10
# [RECHAZADA] intento 414: Pares extra detectados (3). | GCCCAGTCATGAAC... | E=-28.20
# [RECHAZADA] intento 415: Pares extra detectados (5). | CGGCAATAGAACAT... | E=-25.60
# [✓ 124/200] ID=124 E=-27.00 CCATCTAGAAGG... PNG=✓
# [RECHAZADA] intento 417: Pares extra detectados (2). | GGAGAATAGCCATA... | E=-23.50
# [RECHAZADA] intento 418: Pares extra detectados (6). | AATACAGGCTCAGC... | E=-28.10
# [RECHAZADA] intento 419: Pares extra detectados (4). | CGTACCTTACACGC... | E=-28.20
# [RECHAZADA] intento 420: Pares extra detectados (3). | TTCAAGCCGTAGGT... | E=-25.60
# [RECHAZADA] intento 421: Pares extra detectados (3). | CACGATGCCAAGTC... | E=-28.00
# [RECHAZADA] intento 422: Pares extra detectados (3). | GAAGATTACCGGTA... | E=-22.60
# [RECHAZADA] intento 423: Pares extra detectados (3). | GAGCGAAATAGACA... | E=-24.70
# [RECHAZADA] intento 424: Pares extra detectados (6). | CTAGAATGAATTGG... | E=-20.50
# [RECHAZADA] intento 425: Pares extra detectados (3). | ACAGGCCTGGGCGT... | E=-31.80
# [RECHAZADA] intento 426: Pares extra detectados (4). | GGCAAACAAAGCTT... | E=-22.40
# [RECHAZADA] intento 427: Pares extra detectados (5). | CTTGCTTCCACTTG... | E=-26.70
# [RECHAZADA] intento 428: Pares extra detectados (5). | AGTATGTCAAGAGC... | E=-23.40
# [✓ 125/200] ID=125 E=-21.50 AATACGTACCCT... PNG=✓
# [RECHAZADA] intento 430: Pares extra detectados (5). | GGAAAGGCCGGAGC... | E=-32.80
# [✓ 126/200] ID=126 E=-30.30 CCCGCCTACCGC... PNG=✓
# [RECHAZADA] intento 432: Pares extra detectados (3). | ATGGAGGCGGTCTC... | E=-31.60
# [RECHAZADA] intento 433: Pares extra detectados (2). | AAGTCTGCCAGCCA... | E=-27.00
# [RECHAZADA] intento 434: Pares extra detectados (2). | ATTGCGGGGCGGTC... | E=-29.40
# [RECHAZADA] intento 435: Pares extra detectados (3). | TCTCAATCATATGT... | E=-18.90
# [RECHAZADA] intento 436: Pares extra detectados (6). | AGGTCGAGCCCACT... | E=-29.40
# [RECHAZADA] intento 437: Pares extra detectados (2). | GCGAATATCAGCGA... | E=-23.70
# [✓ 127/200] ID=127 E=-20.10 TTGTACATCTTA... PNG=✓
# [RECHAZADA] intento 439: Pares extra detectados (4). | GAGATTAAGGCTGG... | E=-27.00
# [RECHAZADA] intento 440: Pares extra detectados (4). | ATATCTCTGAGTCG... | E=-22.40
# [RECHAZADA] intento 441: Pares extra detectados (5). | CTAACACCACAAAA... | E=-21.50
# [RECHAZADA] intento 442: Pares extra detectados (3). | CTCCCAAGTTGCAC... | E=-28.50
# [✓ 128/200] ID=128 E=-23.10 CGACGGAATCAT... PNG=✓
# [RECHAZADA] intento 444: Pares extra detectados (2). | GACACGGGATAGGT... | E=-27.10
# [✓ 129/200] ID=129 E=-23.00 ATGCGCAGAACA... PNG=✓
# [RECHAZADA] intento 446: Pares extra detectados (3). | TCTGCCCATGGCTG... | E=-30.10
# [RECHAZADA] intento 447: Pares extra detectados (5). | TATTAGTCGAGCAC... | E=-21.90
# [RECHAZADA] intento 448: Pares extra detectados (4). | GGCTGGTCCTAAGA... | E=-29.80
# [RECHAZADA] intento 449: Pares extra detectados (5). | TTTGCTAGGCGGCG... | E=-30.20
# [✓ 130/200] ID=130 E=-27.80 CCGCGCGAACAG... PNG=✓
# [RECHAZADA] intento 451: Pares extra detectados (6). | CGTCGAAATGCTAA... | E=-24.40
# [RECHAZADA] intento 452: Pares extra detectados (6). | AGGATGTACAGCCT... | E=-28.20
# [RECHAZADA] intento 453: Pares extra detectados (7). | CCAGTGTATGTGGG... | E=-28.00
# [RECHAZADA] intento 454: Pares extra detectados (6). | AACACCCCACTATC... | E=-26.70
# [RECHAZADA] intento 455: Pares extra detectados (2). | ACGAGAACATCGGT... | E=-23.30
# [RECHAZADA] intento 456: Pares extra detectados (6). | GTTGGGGGGTTCTT... | E=-34.10
# [✓ 131/200] ID=131 E=-19.60 GTGATATTTCGC... PNG=✓
# [RECHAZADA] intento 458: Pares extra detectados (4). | CCTTCAGTGGGGGT... | E=-29.70
# [✓ 132/200] ID=132 E=-30.70 CCACCGCTCGCG... PNG=✓
# [RECHAZADA] intento 460: Pares extra detectados (4). | CAGTATCTCTGCTA... | E=-24.30
# [✓ 133/200] ID=133 E=-27.00 GTACTCTGTCCA... PNG=✓
# [RECHAZADA] intento 462: Pares extra detectados (4). | TGTATAGCGCGCGT... | E=-26.70
# [RECHAZADA] intento 463: Pares extra detectados (4). | GGATAAAATTGGGT... | E=-22.30
# [RECHAZADA] intento 464: Pares extra detectados (5). | CAATTGCTAAGGCG... | E=-22.80
# [RECHAZADA] intento 465: Pares extra detectados (3). | AGGGCACCAACGAG... | E=-29.30
# [RECHAZADA] intento 466: Pares extra detectados (3). | AGACAGGCGTCACC... | E=-27.70
# [RECHAZADA] intento 467: Pares extra detectados (7). | ATTTGCTAATATCA... | E=-19.50
# [✓ 134/200] ID=134 E=-22.00 GGAAACAGTATC... PNG=✓
# [✓ 135/200] ID=135 E=-28.00 CGCTCCAGGTTC... PNG=✓
# [RECHAZADA] intento 470: Pares extra detectados (2). | TCTAGTTTAGTCAG... | E=-22.00
# [✓ 136/200] ID=136 E=-22.30 AGAGACTGATGA... PNG=✓
# [RECHAZADA] intento 472: Pares extra detectados (4). | GTACCTTCTGCGGG... | E=-29.40
# [RECHAZADA] intento 473: Pares extra detectados (3). | ACCCCACACCTGTA... | E=-27.00
# [RECHAZADA] intento 474: Pares extra detectados (4). | TATCGTATCATAAA... | E=-18.70
# [RECHAZADA] intento 475: Pares extra detectados (6). | CACGACTGATTTTC... | E=-23.20
# [RECHAZADA] intento 476: Pares extra detectados (4). | CTGTCCCGAACTAC... | E=-27.10
# [RECHAZADA] intento 477: Pares extra detectados (5). | AACAACCTCCGCAC... | E=-26.50
# [✓ 137/200] ID=137 E=-21.70 CATCTTACCTTC... PNG=✓
# [RECHAZADA] intento 479: Pares extra detectados (5). | GGTAGCCATCAAAC... | E=-31.70
# [✓ 138/200] ID=138 E=-19.90 TATCTCGATTGA... PNG=✓
# [✓ 139/200] ID=139 E=-26.70 GGATCCTGAGAG... PNG=✓
# [RECHAZADA] intento 482: Pares extra detectados (5). | TGCCTGCATTGAAG... | E=-25.40
# [RECHAZADA] intento 483: Pares extra detectados (3). | TAAGCACGAAAAAA... | E=-18.00
# [✓ 140/200] ID=140 E=-22.30 TCTGTCATTACT... PNG=✓
# [RECHAZADA] intento 485: Pares extra detectados (5). | GCGACCAGAGGAAA... | E=-29.80
# [✓ 141/200] ID=141 E=-19.40 AATTGACTTGTG... PNG=✓
# [RECHAZADA] intento 487: Pares extra detectados (3). | AGCAGCGGACCATC... | E=-30.70
# [RECHAZADA] intento 488: Pares extra detectados (4). | GCCGACGATGTTTA... | E=-25.20
# [RECHAZADA] intento 489: Pares extra detectados (4). | GAGGGTGGTTGAGA... | E=-28.90
# [✓ 142/200] ID=142 E=-20.30 TAGCTACTGCAA... PNG=✓
# [✓ 143/200] ID=143 E=-15.70 AATGTTTTTCAC... PNG=✓
# [✓ 144/200] ID=144 E=-16.40 ATCGGATTGTTA... PNG=✓
# [✓ 145/200] ID=145 E=-26.20 GAAGTTCCTCTG... PNG=✓
# [RECHAZADA] intento 494: Pares extra detectados (5). | GGGGAGGATGTGAA... | E=-30.20
# [RECHAZADA] intento 495: Pares extra detectados (3). | CGGATGTCGGACAG... | E=-28.10
# [RECHAZADA] intento 496: Pares extra detectados (5). | AGTTGGCTCCTTCT... | E=-28.70
# [RECHAZADA] intento 497: Pares extra detectados (5). | ACGTCCCCGCTTAT... | E=-25.70
# [✓ 146/200] ID=146 E=-19.70 AACAGATTTACC... PNG=✓
# [RECHAZADA] intento 499: Pares extra detectados (5). | ATATGGAGCAAACA... | E=-20.90
# [RECHAZADA] intento 500: Pares extra detectados (6). | TCGCTCGTAGGGAT... | E=-28.70
# [✓ 147/200] ID=147 E=-22.40 ACGATTCGCTGG... PNG=✓
# [RECHAZADA] intento 502: Pares extra detectados (6). | GTGTAACTTCACGC... | E=-24.80
# [✓ 148/200] ID=148 E=-29.80 CACGGGGTCGCA... PNG=✓
# [✓ 149/200] ID=149 E=-21.60 TCGTGTAATCCC... PNG=✓
# [RECHAZADA] intento 505: Pares extra detectados (3). | GGGCTCTTGTACAC... | E=-29.20
# [RECHAZADA] intento 506: Pares extra detectados (4). | AGCGCAGGACACCG... | E=-36.40
# [RECHAZADA] intento 507: Pares extra detectados (3). | CCACTGCAAGTCGA... | E=-26.50
# [✓ 150/200] ID=150 E=-24.70 AGCGAGGTAAGC... PNG=✓
# [RECHAZADA] intento 509: Pares extra detectados (3). | AATTACTACCAATG... | E=-18.50
# [RECHAZADA] intento 510: Pares extra detectados (4). | AAGGGACGGTCATA... | E=-26.10
# [✓ 151/200] ID=151 E=-19.50 TTTTCACTCATG... PNG=✓
# [RECHAZADA] intento 512: Pares extra detectados (3). | GTATCACCCTTGGG... | E=-28.40
# [RECHAZADA] intento 513: Pares extra detectados (4). | CGCGCGCGTAGGTT... | E=-31.90
# [RECHAZADA] intento 514: Pares extra detectados (6). | ACTGTCAACCGAAT... | E=-21.90
# [✓ 152/200] ID=152 E=-20.80 AATAGGCAGTTT... PNG=✓
# [✓ 153/200] ID=153 E=-23.80 ACCCAAAACAGT... PNG=✓
# [✓ 154/200] ID=154 E=-27.10 TGCTCGCAATCG... PNG=✓
# [RECHAZADA] intento 518: Pares extra detectados (3). | GGGTATCGGCAATT... | E=-23.60
# [✓ 155/200] ID=155 E=-23.70 ACAATGGGAGAT... PNG=✓
# [RECHAZADA] intento 520: Pares extra detectados (4). | GATCCGGCTGCTTG... | E=-30.70
# [RECHAZADA] intento 521: Pares extra detectados (4). | CTGGCAAGACGACC... | E=-31.70
# [RECHAZADA] intento 522: Pares extra detectados (7). | TTCGTTAAAGGGCT... | E=-22.30
# [✓ 156/200] ID=156 E=-31.70 GCCTGTGCTGGG... PNG=✓
# [RECHAZADA] intento 524: Pares extra detectados (5). | CATTCGATCAGTGT... | E=-23.80
# [RECHAZADA] intento 525: Pares extra detectados (4). | TTATAGTAGTTGTA... | E=-24.40
# [✓ 157/200] ID=157 E=-22.40 GCACCTATAAGG... PNG=✓
# [RECHAZADA] intento 527: Pares extra detectados (5). | TGAGGTGTGATCGA... | E=-30.20
# [✓ 158/200] ID=158 E=-25.20 CAAGAGAGAACC... PNG=✓
# [✓ 159/200] ID=159 E=-27.80 GCCCATCGCCAT... PNG=✓
# [RECHAZADA] intento 530: Pares extra detectados (7). | CTAAAGGCCGGTCT... | E=-28.40
# [RECHAZADA] intento 531: Pares extra detectados (3). | GAGTAACAAAGTCA... | E=-19.80
# [✓ 160/200] ID=160 E=-23.20 CTGTCTCTACGA... PNG=✓
# [RECHAZADA] intento 533: Pares extra detectados (4). | CATAAGAATTTTTC... | E=-14.80
# [RECHAZADA] intento 534: Pares extra detectados (6). | TGGATACCCTACTC... | E=-32.90
# [✓ 161/200] ID=161 E=-25.80 AACCGCATTGTG... PNG=✓
# [✓ 162/200] ID=162 E=-26.80 CCGCGATGAGCA... PNG=✓
# [RECHAZADA] intento 537: Pares extra detectados (4). | GTTTTTCTGGCCCA... | E=-25.00
# [RECHAZADA] intento 538: Pares extra detectados (4). | CGTTCTGGCGACGC... | E=-30.30
# [✓ 163/200] ID=163 E=-31.80 CCTGGCCGGGTG... PNG=✓
# [✓ 164/200] ID=164 E=-21.90 ATCGTTATTCCC... PNG=✓
# [RECHAZADA] intento 541: Pares extra detectados (6). | TCGCAACGACTCCC... | E=-28.90
# [RECHAZADA] intento 542: Pares extra detectados (2). | GATTAACCCGCTAC... | E=-24.00
# [✓ 165/200] ID=165 E=-21.10 CTAAACGGAATC... PNG=✓
# [RECHAZADA] intento 544: Pares extra detectados (7). | CGCACACTAGCCAT... | E=-31.60
# [RECHAZADA] intento 545: Pares extra detectados (6). | GAGGATGAACTCGA... | E=-29.70
# [RECHAZADA] intento 546: Pares extra detectados (4). | TCTTCCAGGCGATT... | E=-25.60
# [RECHAZADA] intento 547: Pares extra detectados (6). | CGTTAGGCCGGATG... | E=-30.20
# [RECHAZADA] intento 548: Pares extra detectados (4). | GTCTCTGCGCCGGC... | E=-31.70
# [RECHAZADA] intento 549: Pares extra detectados (4). | TGAGGGGTACGGTT... | E=-26.00
# [✓ 166/200] ID=166 E=-18.90 GGAGTAAAAAAA... PNG=✓
# [RECHAZADA] intento 551: Pares extra detectados (6). | TTACAGGCCTATTC... | E=-22.50
# [RECHAZADA] intento 552: Pares extra detectados (5). | GATGCCGCACCGGT... | E=-37.20
# [✓ 167/200] ID=167 E=-24.40 ACGCAGACATAG... PNG=✓
# [RECHAZADA] intento 554: Pares extra detectados (2). | AGGGCGTGGTACAA... | E=-27.70
# [✓ 168/200] ID=168 E=-22.80 TAAAGTGTTGGG... PNG=✓
# [RECHAZADA] intento 556: Pares extra detectados (3). | AATACATCCCATGC... | E=-22.10
# [RECHAZADA] intento 557: Pares extra detectados (4). | CCGGACAAACTTGA... | E=-25.60
# [RECHAZADA] intento 558: Pares extra detectados (4). | CAACAATATGCTGG... | E=-26.10
# [RECHAZADA] intento 559: Pares extra detectados (5). | GCGTGCTATGAACT... | E=-23.60
# [RECHAZADA] intento 560: Pares extra detectados (5). | CAACCGGGTCGATT... | E=-31.30
# [✓ 169/200] ID=169 E=-16.50 TGCCGAATTAAA... PNG=✓
# [✓ 170/200] ID=170 E=-22.20 TCTTTCTGAGAG... PNG=✓
# [RECHAZADA] intento 563: Pares extra detectados (5). | TCAAGAGCGCTACG... | E=-25.80
# [✓ 171/200] ID=171 E=-20.90 AGTTAGATGTTG... PNG=✓
# [✓ 172/200] ID=172 E=-29.30 CCGGAGCTGCCG... PNG=✓
# [RECHAZADA] intento 566: Pares extra detectados (6). | GTTACACACTTGAA... | E=-26.30
# [RECHAZADA] intento 567: Pares extra detectados (5). | TGGTATCTTACGCT... | E=-23.50
# [✓ 173/200] ID=173 E=-24.40 TGGCCATGTATG... PNG=✓
# [RECHAZADA] intento 569: Pares extra detectados (4). | GTGTGACAGTACAG... | E=-28.40
# [RECHAZADA] intento 570: Pares extra detectados (8). | CCAGTACAGAGCTG... | E=-30.30
# [RECHAZADA] intento 571: Pares extra detectados (3). | CTGTATACCAGAAT... | E=-22.50
# [RECHAZADA] intento 572: Pares extra detectados (3). | TCACCGTCCTACGA... | E=-25.40
# [RECHAZADA] intento 573: Pares extra detectados (3). | TTTGTCCGGGAGCG... | E=-31.20
# [✓ 174/200] ID=174 E=-27.70 GCCGGGGATCAG... PNG=✓
# [✓ 175/200] ID=175 E=-17.10 TTCTGTCTGTAA... PNG=✓
# [RECHAZADA] intento 576: Pares extra detectados (3). | GTGAGATATCTCAC... | E=-24.40
# [RECHAZADA] intento 577: Pares extra detectados (5). | ACAAAACTGACCTG... | E=-21.90
# [✓ 176/200] ID=176 E=-24.80 CATGGAGGTACG... PNG=✓
# [✓ 177/200] ID=177 E=-29.50 CCTCGGGGTTTC... PNG=✓
# [RECHAZADA] intento 580: Pares extra detectados (5). | CAGCTGATGATCAG... | E=-25.50
# [✓ 178/200] ID=178 E=-20.50 TGTTGCTGACAT... PNG=✓
# [RECHAZADA] intento 582: Pares extra detectados (4). | GGTTGCGGGGCTCG... | E=-33.50
# [RECHAZADA] intento 583: Pares extra detectados (5). | AGACGTATGGCTAA... | E=-29.80
# [✓ 179/200] ID=179 E=-20.40 TTGCGCGAAATT... PNG=✓
# [RECHAZADA] intento 585: Pares extra detectados (4). | AAAAGCCAGCGCGG... | E=-29.60
# [RECHAZADA] intento 586: Pares extra detectados (4). | CAGTTTCTTAAGGG... | E=-24.90
# [RECHAZADA] intento 587: Pares extra detectados (5). | TACGCTAGCGCTGT... | E=-25.60
# [✓ 180/200] ID=180 E=-18.20 GTCCTTGTATTT... PNG=✓
# [✓ 181/200] ID=181 E=-21.00 AACCGCCAATAG... PNG=✓
# [RECHAZADA] intento 590: Pares extra detectados (5). | AAAAGAAAGGTCGT... | E=-21.20
# [RECHAZADA] intento 591: Pares extra detectados (7). | TCTTCAATTTAGGC... | E=-22.80
# [RECHAZADA] intento 592: Pares extra detectados (6). | CACGTTCGTACCGG... | E=-35.30
# [RECHAZADA] intento 593: Pares extra detectados (6). | TCAAGGGACTCATC... | E=-27.20
# [RECHAZADA] intento 594: Pares extra detectados (5). | CTTATTAAGAGAGC... | E=-21.10
# [RECHAZADA] intento 595: Pares extra detectados (4). | GCTCCATTGACACT... | E=-30.30
# [RECHAZADA] intento 596: Pares extra detectados (5). | AGATTCTCGCAACA... | E=-26.60
# [RECHAZADA] intento 597: Pares extra detectados (3). | ACATTTGCGTGGGG... | E=-28.30
# [✓ 182/200] ID=182 E=-23.30 ACTTGGATCCAG... PNG=✓
# [RECHAZADA] intento 599: Pares extra detectados (4). | TTTTGCGTCACCCA... | E=-26.40
# [✓ 183/200] ID=183 E=-19.20 ATCTTTACGTAG... PNG=✓
# [✓ 184/200] ID=184 E=-29.00 GAGGGCCGATAC... PNG=✓
# [RECHAZADA] intento 602: Pares extra detectados (4). | ATCTGTGGTTACCG... | E=-24.30
# [✓ 185/200] ID=185 E=-21.30 CCTGGATTACAT... PNG=✓
# [RECHAZADA] intento 604: Pares extra detectados (4). | TATAAGCGTCGAAC... | E=-22.10
# [RECHAZADA] intento 605: Pares extra detectados (6). | CATGACAGAGTGCC... | E=-28.40
# [RECHAZADA] intento 606: Pares extra detectados (4). | GGCCCTTACAAACC... | E=-30.60
# [✓ 186/200] ID=186 E=-19.40 ATACATCCCTAA... PNG=✓
# [✓ 187/200] ID=187 E=-26.40 GTCTGATACCCC... PNG=✓
# [RECHAZADA] intento 609: Pares extra detectados (2). | TTATAAATAGTTCT... | E=-14.90
# [RECHAZADA] intento 610: Pares extra detectados (4). | ACATACCTATCAAG... | E=-21.00
# [RECHAZADA] intento 611: Pares extra detectados (5). | GTGGGATTGCGTCC... | E=-33.80
# [RECHAZADA] intento 612: Pares extra detectados (4). | CGGGGTCAGGAATG... | E=-32.90
# [RECHAZADA] intento 613: Pares extra detectados (6). | AAGGTGCAGAGTTT... | E=-27.20
# [✓ 188/200] ID=188 E=-24.50 GCGCTAATGAGT... PNG=✓
# [RECHAZADA] intento 615: Pares extra detectados (3). | GGTGTTCGATGTCT... | E=-26.10
# [RECHAZADA] intento 616: Pares extra detectados (4). | GTAAGGGTATCAGA... | E=-25.20
# [✓ 189/200] ID=189 E=-24.80 CTTTTCGAGGGG... PNG=✓
# [RECHAZADA] intento 618: Pares extra detectados (5). | TCAGTCGTTACAAG... | E=-22.80
# [RECHAZADA] intento 619: Pares extra detectados (3). | CAGGCCACGCTAAC... | E=-29.80
# [RECHAZADA] intento 620: Pares extra detectados (4). | GAGGGGGGCACTGA... | E=-37.70
# [RECHAZADA] intento 621: Pares extra detectados (4). | CCGCTTGCGACCTT... | E=-28.40
# [RECHAZADA] intento 622: Pares extra detectados (6). | AAAGCCGAATGGTC... | E=-26.40
# [✓ 190/200] ID=190 E=-22.00 CTCATGGATACT... PNG=✓
# [✓ 191/200] ID=191 E=-27.20 TAGCTGCGCGAG... PNG=✓
# [RECHAZADA] intento 625: Pares extra detectados (2). | CTAAACAGCTGCGC... | E=-25.10
# [RECHAZADA] intento 626: Pares extra detectados (4). | AACCGGCGATTTAA... | E=-21.10
# [RECHAZADA] intento 627: Pares extra detectados (5). | ACCATCGGTGGAAG... | E=-27.00
# [✓ 192/200] ID=192 E=-28.70 TCGCGCATCGCC... PNG=✓
# [RECHAZADA] intento 629: Pares extra detectados (5). | GGTGCCATGTTATT... | E=-27.00
# [✓ 193/200] ID=193 E=-21.20 GAATTCGCCAGT... PNG=✓
# [RECHAZADA] intento 631: Pares extra detectados (4). | GGGCATCTACGAAG... | E=-26.60
# [RECHAZADA] intento 632: Pares extra detectados (5). | ATGCGGGGGCATGC... | E=-34.20
# [RECHAZADA] intento 633: Pares extra detectados (3). | CTCCTAGTCCACTG... | E=-27.00
# [RECHAZADA] intento 634: Pares extra detectados (4). | CATGGGAAGGGAGA... | E=-30.10
# [RECHAZADA] intento 635: Pares extra detectados (4). | TAACCGCCATTCGT... | E=-26.50
# [RECHAZADA] intento 636: Pares extra detectados (4). | CGACCGTCGCACGG... | E=-30.60
# [✓ 194/200] ID=194 E=-20.90 TAGCACAGAAAC... PNG=✓
# [✓ 195/200] ID=195 E=-24.00 CCAATAGCCTAC... PNG=✓
# [RECHAZADA] intento 639: Pares extra detectados (5). | TCCACCGAATGACC... | E=-28.40
# [RECHAZADA] intento 640: Pares extra detectados (5). | GACTAAGGCGTTAG... | E=-27.00
# [✓ 196/200] ID=196 E=-29.20 ATCCGTCTGGGA... PNG=✓
# [RECHAZADA] intento 642: Pares extra detectados (6). | ACCGAGGCTCTTTA... | E=-26.80
# [RECHAZADA] intento 643: Pares extra detectados (3). | CCATATGAATTCCA... | E=-19.50
# [RECHAZADA] intento 644: Pares extra detectados (6). | ATAAGTTACGCCGT... | E=-25.40
# [RECHAZADA] intento 645: Pares extra detectados (2). | CCGGCTGCGACAGG... | E=-31.80
# [✓ 197/200] ID=197 E=-24.10 ACTGAGAGGAAT... PNG=✓
# [✓ 198/200] ID=198 E=-30.30 GTCGGGTGACGC... PNG=✓
# [RECHAZADA] intento 648: Pares extra detectados (3). | AGGGTCTAGGACAC... | E=-31.10
# [RECHAZADA] intento 649: Pares extra detectados (7). | GGAGCGGCTTGAAG... | E=-31.40
# [RECHAZADA] intento 650: Pares extra detectados (4). | CAGACTAGTAGATA... | E=-22.00
# [✓ 199/200] ID=199 E=-31.20 CACCCCCATGGC... PNG=✓
# [RECHAZADA] intento 652: Pares extra detectados (4). | ATTTGTGTTCAGGT... | E=-21.10
# [RECHAZADA] intento 653: Pares extra detectados (5). | CGTTTGGAACGCTG... | E=-24.60
# [RECHAZADA] intento 654: Pares extra detectados (2). | TGAAACATTTTATA... | E=-13.50
# [RECHAZADA] intento 655: Pares extra detectados (5). | CAGCCCGGCATATT... | E=-27.90
# [✓ 200/200] ID=200 E=-22.50 TACACAACACGA... PNG=✓
#
# ✅ 200 secuencias válidas en 656 intentos.
# ✅ Vienna: resultados.vienna
# ✅ CSV: resultados_summary.csv
#
# ======================================================================
# 🏆 TOP ESTRUCTURAS MÁS ESTABLES (energía libre de Gibbs)
# ======================================================================
# 1. ID=163 | E=-31.80 kcal/mol | CCTGGCCGGGTGAGT... | PNG=✓
# 2. ID=156 | E=-31.70 kcal/mol | GCCTGTGCTGGGGAA... | PNG=✓
# 3. ID=199 | E=-31.20 kcal/mol | CACCCCCATGGCACG... | PNG=✓
# 4. ID=132 | E=-30.70 kcal/mol | CCACCGCTCGCGAGT... | PNG=✓
# 5. ID= 48 | E=-30.50 kcal/mol | GCGGGCGTGTCCGAC... | PNG=✓
#
# 📊 Resumen: 200 secuencias | 200 imágenes PNG generadas
# 📁 Archivos en: plots/ | resultados.vienna | resultados_summary.csv
# ======================================================================

# %%
import shutil

# Comprime la carpeta 'plots' en un archivo ZIP
shutil.make_archive("plots", 'zip', "plots")

print("✅ Carpeta 'plots/' comprimida como 'plots.zip'")
# Out:
# ✅ Carpeta 'plots/' comprimida como 'plots.zip'
